# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.8690529955452602, score: 48
# Scores: (min: 48, avg: 48, max: 48)
#
# Run: 2, exploration: 0.7744209942832988, score: 24
# Scores: (min: 24, avg: 36, max: 48)
#
# Run: 3, exploration: 0.7040696960536299, score: 20
# Scores: (min: 20, avg: 30.666666666666668, max: 48)
#
# Run: 4, exploration: 0.6433260027715241, score: 19
# Scores: (min: 19, avg: 27.75, max: 48)
#
# Run: 5, exploration: 0.6211445383053219, score: 8
# Scores: (min: 8, avg: 23.8, max: 48)
#
# Run: 6, exploration: 0.5878229785513479, score: 12
# Scores: (min: 8, avg: 21.833333333333332, max: 48)
#
# Run: 7, exploration: 0.5507399854171277, score: 14
# Scores: (min: 8, avg: 20.714285714285715, max: 48)
#
# Run: 8, exploration: 0.5159963842937159, score: 14
# Scores: (min: 8, avg: 19.875, max: 48)
#
# Run: 9, exploration: 0.4598090507939749, score: 24
# Scores: (min: 8, avg: 20.333333333333332, max: 48)
#
# Run: 10, exploration: 0.43732904629000013, score: 11
# Scores: (min: 8, avg: 19.4, max: 48)
#
# Run: 11, exploration: 0.4159480862733536, score: 11
# Scores: (min: 8, avg: 18.636363636363637, max: 48)
#
# Run: 12, exploration: 0.3897078735047413, score: 14
# Scores: (min: 8, avg: 18.25, max: 48)
#
# Run: 13, exploration: 0.36880183088056995, score: 12
# Scores: (min: 8, avg: 17.76923076923077, max: 48)
#
# Run: 14, exploration: 0.35608578229633, score: 8
# Scores: (min: 8, avg: 17.071428571428573, max: 48)
#
# Run: 15, exploration: 0.3403786882983606, score: 10
# Scores: (min: 8, avg: 16.6, max: 48)
#
# Run: 16, exploration: 0.3237376186352221, score: 11
# Scores: (min: 8, avg: 16.25, max: 48)
#
# Run: 17, exploration: 0.3063705780533402, score: 12
# Scores: (min: 8, avg: 16, max: 48)
#
# Run: 18, exploration: 0.2943280830920294, score: 9
# Scores: (min: 8, avg: 15.61111111111111, max: 48)
#
# Run: 19, exploration: 0.2799384215094006, score: 11
# Scores: (min: 8, avg: 15.368421052631579, max: 48)
#
# Run: 20, exploration: 0.26759021970270175, score: 10
# Scores: (min: 8, avg: 15.1, max: 48)
#
# Run: 21, exploration: 0.2519690537792925, score: 13
# Scores: (min: 8, avg: 15, max: 48)
#
# Run: 22, exploration: 0.23965031961336, score: 11
# Scores: (min: 8, avg: 14.818181818181818, max: 48)
#
# Run: 23, exploration: 0.23023039494318503, score: 9
# Scores: (min: 8, avg: 14.565217391304348, max: 48)
#
# Run: 24, exploration: 0.22007483514733558, score: 10
# Scores: (min: 8, avg: 14.375, max: 48)
#
# Run: 25, exploration: 0.21036724137609603, score: 10
# Scores: (min: 8, avg: 14.2, max: 48)
#
# Run: 26, exploration: 0.20209834538617025, score: 9
# Scores: (min: 8, avg: 14, max: 48)
#
# Run: 27, exploration: 0.19318370215794672, score: 10
# Scores: (min: 8, avg: 13.851851851851851, max: 48)
#
# Run: 28, exploration: 0.18190617987607657, score: 13
# Scores: (min: 8, avg: 13.821428571428571, max: 48)
#
# Run: 29, exploration: 0.1518722266715875, score: 37
# Scores: (min: 8, avg: 14.620689655172415, max: 48)
#
# Run: 30, exploration: 0.1135578192100607, score: 59
# Scores: (min: 8, avg: 16.1, max: 59)
#
# Run: 31, exploration: 0.09108200798387568, score: 45
# Scores: (min: 8, avg: 17.032258064516128, max: 59)
#
# Run: 32, exploration: 0.07719590465791494, score: 34
# Scores: (min: 8, avg: 17.5625, max: 59)
#
# Run: 33, exploration: 0.06348840406243188, score: 40
# Scores: (min: 8, avg: 18.242424242424242, max: 59)
#
# Run: 34, exploration: 0.05743227569078546, score: 21
# Scores: (min: 8, avg: 18.323529411764707, max: 59)
#
# Run: 35, exploration: 0.045605554379880814, score: 47
# Scores: (min: 8, avg: 19.142857142857142, max: 59)
#
# Run: 36, exploration: 0.0386526615487428, score: 34
# Scores: (min: 8, avg: 19.555555555555557, max: 59)
#
# Run: 37, exploration: 0.032924408985721944, score: 33
# Scores: (min: 8, avg: 19.91891891891892, max: 59)
#
# Run: 38, exploration: 0.029933432588273214, score: 20
# Scores: (min: 8, avg: 19.92105263157895, max: 59)
#
# Run: 39, exploration: 0.025754252208694463, score: 31
# Scores: (min: 8, avg: 20.205128205128204, max: 59)
#
# Run: 40, exploration: 0.022949847368015076, score: 24
# Scores: (min: 8, avg: 20.3, max: 59)
#
# Run: 41, exploration: 0.01954872266561937, score: 33
# Scores: (min: 8, avg: 20.609756097560975, max: 59)
#
# Run: 42, exploration: 0.013156542237201536, score: 80
# Scores: (min: 8, avg: 22.023809523809526, max: 80)
#
# Run: 43, exploration: 0.010447285872500434, score: 47
# Scores: (min: 8, avg: 22.6046511627907, max: 80)
#
# Run: 44, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 23.34090909090909, max: 80)
#
# Run: 45, exploration: 0.01, score: 96
# Scores: (min: 8, avg: 24.955555555555556, max: 96)
#
# Run: 46, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 25, max: 96)
#
# Run: 47, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 25.085106382978722, max: 96)
#
# Run: 48, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 25.416666666666668, max: 96)
#
# Run: 49, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 25.897959183673468, max: 96)
#
# Run: 50, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 26.08, max: 96)
#
# Run: 51, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 26.333333333333332, max: 96)
#
# Run: 52, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 26.73076923076923, max: 96)
#
# Run: 53, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 26.9811320754717, max: 96)
#
# Run: 54, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 27.09259259259259, max: 96)
#
# Run: 55, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 27.527272727272727, max: 96)
#
# Run: 56, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 27.875, max: 96)
#
# Run: 57, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 27.92982456140351, max: 96)
#
# Run: 58, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 28.20689655172414, max: 96)
#
# Run: 59, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 28.74576271186441, max: 96)
#
# Run: 60, exploration: 0.01, score: 90
# Scores: (min: 8, avg: 29.766666666666666, max: 96)
#
# Run: 61, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 30.19672131147541, max: 96)
#
# Run: 62, exploration: 0.01, score: 76
# Scores: (min: 8, avg: 30.93548387096774, max: 96)
#
# Run: 63, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 31.349206349206348, max: 96)
#
# Run: 64, exploration: 0.01, score: 91
# Scores: (min: 8, avg: 32.28125, max: 96)
#
# Run: 65, exploration: 0.01, score: 103
# Scores: (min: 8, avg: 33.36923076923077, max: 103)
#
# Run: 66, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 33.74242424242424, max: 103)
#
# Run: 67, exploration: 0.01, score: 75
# Scores: (min: 8, avg: 34.35820895522388, max: 103)
#
# Run: 68, exploration: 0.01, score: 65
# Scores: (min: 8, avg: 34.80882352941177, max: 103)
#
# Run: 69, exploration: 0.01, score: 72
# Scores: (min: 8, avg: 35.34782608695652, max: 103)
#
# Run: 70, exploration: 0.01, score: 90
# Scores: (min: 8, avg: 36.128571428571426, max: 103)
#
# Run: 71, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 36.647887323943664, max: 103)
#
# Run: 72, exploration: 0.01, score: 90
# Scores: (min: 8, avg: 37.388888888888886, max: 103)
#
# Run: 73, exploration: 0.01, score: 105
# Scores: (min: 8, avg: 38.31506849315068, max: 105)
#
# Run: 74, exploration: 0.01, score: 83
# Scores: (min: 8, avg: 38.91891891891892, max: 105)
#
# Run: 75, exploration: 0.01, score: 127
# Scores: (min: 8, avg: 40.093333333333334, max: 127)
#
# Run: 76, exploration: 0.01, score: 96
# Scores: (min: 8, avg: 40.828947368421055, max: 127)
#
# Run: 77, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 42.42857142857143, max: 164)
#
# Run: 78, exploration: 0.01, score: 110
# Scores: (min: 8, avg: 43.294871794871796, max: 164)
#
# Run: 79, exploration: 0.01, score: 134
# Scores: (min: 8, avg: 44.44303797468354, max: 164)
#
# Run: 80, exploration: 0.01, score: 103
# Scores: (min: 8, avg: 45.175, max: 164)
#
# Run: 81, exploration: 0.01, score: 97
# Scores: (min: 8, avg: 45.81481481481482, max: 164)
#
# Run: 82, exploration: 0.01, score: 104
# Scores: (min: 8, avg: 46.52439024390244, max: 164)
#
# Run: 83, exploration: 0.01, score: 122
# Scores: (min: 8, avg: 47.433734939759034, max: 164)
#
# Run: 84, exploration: 0.01, score: 108
# Scores: (min: 8, avg: 48.154761904761905, max: 164)
#
# Run: 85, exploration: 0.01, score: 163
# Scores: (min: 8, avg: 49.50588235294118, max: 164)
#
# Run: 86, exploration: 0.01, score: 175
# Scores: (min: 8, avg: 50.96511627906977, max: 175)
#
# Run: 87, exploration: 0.01, score: 159
# Scores: (min: 8, avg: 52.206896551724135, max: 175)
#
# Run: 88, exploration: 0.01, score: 144
# Scores: (min: 8, avg: 53.25, max: 175)
# Run: 89, exploration: 0.01, score: 162
# Scores: (min: 8, avg: 54.47191011235955, max: 175)
#
# Run: 90, exploration: 0.01, score: 198
# Scores: (min: 8, avg: 56.06666666666667, max: 198)
#
# Run: 91, exploration: 0.01, score: 141
# Scores: (min: 8, avg: 57, max: 198)
#
# Run: 92, exploration: 0.01, score: 141
# Scores: (min: 8, avg: 57.91304347826087, max: 198)
#
# Run: 93, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 58.70967741935484, max: 198)
#
# Run: 94, exploration: 0.01, score: 128
# Scores: (min: 8, avg: 59.4468085106383, max: 198)
#
# Run: 95, exploration: 0.01, score: 128
# Scores: (min: 8, avg: 60.16842105263158, max: 198)
#
# Run: 96, exploration: 0.01, score: 149
# Scores: (min: 8, avg: 61.09375, max: 198)
#
# Run: 97, exploration: 0.01, score: 135
# Scores: (min: 8, avg: 61.855670103092784, max: 198)
#
# Run: 98, exploration: 0.01, score: 118
# Scores: (min: 8, avg: 62.42857142857143, max: 198)
#
# Run: 99, exploration: 0.01, score: 102
# Scores: (min: 8, avg: 62.82828282828283, max: 198)
#
# Run: 100, exploration: 0.01, score: 125
# Scores: (min: 8, avg: 63.45, max: 198)
#
# Run: 101, exploration: 0.01, score: 118
# Scores: (min: 8, avg: 64.15, max: 198)
#
# Run: 102, exploration: 0.01, score: 117
# Scores: (min: 8, avg: 65.08, max: 198)
#
# Run: 103, exploration: 0.01, score: 122
# Scores: (min: 8, avg: 66.1, max: 198)
#
# Run: 104, exploration: 0.01, score: 149
# Scores: (min: 8, avg: 67.4, max: 198)
#
# Run: 105, exploration: 0.01, score: 103
# Scores: (min: 8, avg: 68.35, max: 198)
#
# Run: 106, exploration: 0.01, score: 162
# Scores: (min: 8, avg: 69.85, max: 198)
#
# Run: 107, exploration: 0.01, score: 138
# Scores: (min: 8, avg: 71.09, max: 198)
#
# Run: 108, exploration: 0.01, score: 142
# Scores: (min: 8, avg: 72.37, max: 198)
#
# Run: 109, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 73.64, max: 198)
#
# Run: 110, exploration: 0.01, score: 126
# Scores: (min: 8, avg: 74.79, max: 198)
#
# Run: 111, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 76, max: 198)
#
# Run: 112, exploration: 0.01, score: 133
# Scores: (min: 8, avg: 77.19, max: 198)
#
# Run: 113, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 78.58, max: 198)
#
# Run: 114, exploration: 0.01, score: 141
# Scores: (min: 9, avg: 79.91, max: 198)
#
# Run: 115, exploration: 0.01, score: 125
# Scores: (min: 9, avg: 81.06, max: 198)
#
# Run: 116, exploration: 0.01, score: 139
# Scores: (min: 9, avg: 82.34, max: 198)
#
# Run: 117, exploration: 0.01, score: 129
# Scores: (min: 9, avg: 83.51, max: 198)
#
# Run: 118, exploration: 0.01, score: 147
# Scores: (min: 9, avg: 84.89, max: 198)
#
# Run: 119, exploration: 0.01, score: 140
# Scores: (min: 9, avg: 86.18, max: 198)
#
# Run: 120, exploration: 0.01, score: 129
# Scores: (min: 9, avg: 87.37, max: 198)
#
# Run: 121, exploration: 0.01, score: 129
# Scores: (min: 9, avg: 88.53, max: 198)
#
# Run: 122, exploration: 0.01, score: 143
# Scores: (min: 9, avg: 89.85, max: 198)
#
# Run: 123, exploration: 0.01, score: 141
# Scores: (min: 9, avg: 91.17, max: 198)
#
# Run: 124, exploration: 0.01, score: 135
# Scores: (min: 9, avg: 92.42, max: 198)
#
# Run: 125, exploration: 0.01, score: 148
# Scores: (min: 9, avg: 93.8, max: 198)
#
# Run: 126, exploration: 0.01, score: 144
# Scores: (min: 10, avg: 95.15, max: 198)
#
# Run: 127, exploration: 0.01, score: 116
# Scores: (min: 13, avg: 96.21, max: 198)
#
# Run: 128, exploration: 0.01, score: 137
# Scores: (min: 20, avg: 97.45, max: 198)
#
# Run: 129, exploration: 0.01, score: 134
# Scores: (min: 20, avg: 98.42, max: 198)
#
# Run: 130, exploration: 0.01, score: 133
# Scores: (min: 20, avg: 99.16, max: 198)
#
# Run: 131, exploration: 0.01, score: 136
# Scores: (min: 20, avg: 100.07, max: 198)
#
# Run: 132, exploration: 0.01, score: 142
# Scores: (min: 20, avg: 101.15, max: 198)
#
# Run: 133, exploration: 0.01, score: 139
# Scores: (min: 20, avg: 102.14, max: 198)
#
# Run: 134, exploration: 0.01, score: 133
# Scores: (min: 20, avg: 103.26, max: 198)
#
# Run: 135, exploration: 0.01, score: 142
# Scores: (min: 20, avg: 104.21, max: 198)
#
# Run: 136, exploration: 0.01, score: 150
# Scores: (min: 20, avg: 105.37, max: 198)
#
# Run: 137, exploration: 0.01, score: 144
# Scores: (min: 20, avg: 106.48, max: 198)
#
# Run: 138, exploration: 0.01, score: 132
# Scores: (min: 24, avg: 107.6, max: 198)
#
# Run: 139, exploration: 0.01, score: 133
# Scores: (min: 24, avg: 108.62, max: 198)
#
# Run: 140, exploration: 0.01, score: 131
# Scores: (min: 27, avg: 109.69, max: 198)
#
# Run: 141, exploration: 0.01, score: 140
# Scores: (min: 27, avg: 110.76, max: 198)
#
# Run: 142, exploration: 0.01, score: 140
# Scores: (min: 27, avg: 111.36, max: 198)
#
# Run: 143, exploration: 0.01, score: 140
# Scores: (min: 27, avg: 112.29, max: 198)
#
# Run: 144, exploration: 0.01, score: 122
# Scores: (min: 27, avg: 112.96, max: 198)
#
# Run: 145, exploration: 0.01, score: 133
# Scores: (min: 27, avg: 113.33, max: 198)
#
# Run: 146, exploration: 0.01, score: 150
# Scores: (min: 29, avg: 114.56, max: 198)
#
# Run: 147, exploration: 0.01, score: 134
# Scores: (min: 31, avg: 115.61, max: 198)
#
# Run: 148, exploration: 0.01, score: 144
# Scores: (min: 31, avg: 116.64, max: 198)
#
# Run: 149, exploration: 0.01, score: 134
# Scores: (min: 31, avg: 117.49, max: 198)
#
# Run: 150, exploration: 0.01, score: 120
# Scores: (min: 31, avg: 118.34, max: 198)
#
# Run: 151, exploration: 0.01, score: 143
# Scores: (min: 31, avg: 119.38, max: 198)
#
# Run: 152, exploration: 0.01, score: 138
# Scores: (min: 31, avg: 120.29, max: 198)
#
# Run: 153, exploration: 0.01, score: 144
# Scores: (min: 31, avg: 121.33, max: 198)
#
# Run: 154, exploration: 0.01, score: 137
# Scores: (min: 31, avg: 122.37, max: 198)
#
# Run: 155, exploration: 0.01, score: 157
# Scores: (min: 31, avg: 123.43, max: 198)
#
# Run: 156, exploration: 0.01, score: 142
# Scores: (min: 31, avg: 124.38, max: 198)
#
# Run: 157, exploration: 0.01, score: 136
# Scores: (min: 44, avg: 125.43, max: 198)
#
# Run: 158, exploration: 0.01, score: 162
# Scores: (min: 56, avg: 126.61, max: 198)
#
# Run: 159, exploration: 0.01, score: 129
# Scores: (min: 56, avg: 127.3, max: 198)
#
# Run: 160, exploration: 0.01, score: 136
# Scores: (min: 56, avg: 127.76, max: 198)
#
# Run: 161, exploration: 0.01, score: 124
# Scores: (min: 57, avg: 128.44, max: 198)
#
# Run: 162, exploration: 0.01, score: 126
# Scores: (min: 57, avg: 128.94, max: 198)
#
# Run: 163, exploration: 0.01, score: 143
# Scores: (min: 58, avg: 129.8, max: 198)
#
# Run: 164, exploration: 0.01, score: 144
# Scores: (min: 58, avg: 130.33, max: 198)
#
# Run: 165, exploration: 0.01, score: 123
# Scores: (min: 58, avg: 130.53, max: 198)
#
# Run: 166, exploration: 0.01, score: 174
# Scores: (min: 65, avg: 131.69, max: 198)
#
# Run: 167, exploration: 0.01, score: 128
# Scores: (min: 65, avg: 132.22, max: 198)
#
# Run: 168, exploration: 0.01, score: 149
# Scores: (min: 72, avg: 133.06, max: 198)
#
# Run: 169, exploration: 0.01, score: 131
# Scores: (min: 73, avg: 133.65, max: 198)
#
# Run: 170, exploration: 0.01, score: 160
# Scores: (min: 73, avg: 134.35, max: 198)
#
# Run: 171, exploration: 0.01, score: 134
# Scores: (min: 83, avg: 134.96, max: 198)
#
# Run: 172, exploration: 0.01, score: 158
# Scores: (min: 83, avg: 135.64, max: 198)
#
# Run: 173, exploration: 0.01, score: 137
# Scores: (min: 83, avg: 135.96, max: 198)
#
# Run: 174, exploration: 0.01, score: 149
# Scores: (min: 96, avg: 136.62, max: 198)
#
# Run: 175, exploration: 0.01, score: 157
# Scores: (min: 96, avg: 136.92, max: 198)
#
# Run: 176, exploration: 0.01, score: 136
# Scores: (min: 97, avg: 137.32, max: 198)
#
# Run: 177, exploration: 0.01, score: 143
# Scores: (min: 97, avg: 137.11, max: 198)
#
# Run: 178, exploration: 0.01, score: 144
# Scores: (min: 97, avg: 137.45, max: 198)
#
# Run: 179, exploration: 0.01, score: 152
# Scores: (min: 97, avg: 137.63, max: 198)
#
# Run: 180, exploration: 0.01, score: 170
# Scores: (min: 97, avg: 138.3, max: 198)
#
# Run: 181, exploration: 0.01, score: 143
# Scores: (min: 102, avg: 138.76, max: 198)
#
# Run: 182, exploration: 0.01, score: 132
# Scores: (min: 102, avg: 139.04, max: 198)
#
# Run: 183, exploration: 0.01, score: 149
# Scores: (min: 102, avg: 139.31, max: 198)
#
# Run: 184, exploration: 0.01, score: 148
# Scores: (min: 102, avg: 139.71, max: 198)
#
# Run: 185, exploration: 0.01, score: 132
# Scores: (min: 102, avg: 139.4, max: 198)
#
# Run: 186, exploration: 0.01, score: 124
# Scores: (min: 102, avg: 138.89, max: 198)
#
# Run: 187, exploration: 0.01, score: 131
# Scores: (min: 102, avg: 138.61, max: 198)
#
# Run: 188, exploration: 0.01, score: 146
# Scores: (min: 102, avg: 138.63, max: 198)
# Run: 189, exploration: 0.01, score: 125
# Scores: (min: 102, avg: 138.26, max: 198)
#
# Run: 190, exploration: 0.01, score: 181
# Scores: (min: 102, avg: 138.09, max: 181)
#
# Run: 191, exploration: 0.01, score: 126
# Scores: (min: 102, avg: 137.94, max: 181)
#
# Run: 192, exploration: 0.01, score: 139
# Scores: (min: 102, avg: 137.92, max: 181)
#
# Run: 193, exploration: 0.01, score: 137
# Scores: (min: 102, avg: 137.97, max: 181)
#
# Run: 194, exploration: 0.01, score: 166
# Scores: (min: 102, avg: 138.35, max: 181)
#
# Run: 195, exploration: 0.01, score: 121
# Scores: (min: 102, avg: 138.28, max: 181)
#
# Run: 196, exploration: 0.01, score: 133
# Scores: (min: 102, avg: 138.12, max: 181)
#
# Run: 197, exploration: 0.01, score: 151
# Scores: (min: 102, avg: 138.28, max: 181)
#
# Run: 198, exploration: 0.01, score: 140
# Scores: (min: 102, avg: 138.5, max: 181)
#
# Run: 199, exploration: 0.01, score: 147
# Scores: (min: 103, avg: 138.95, max: 181)
#
# Run: 200, exploration: 0.01, score: 141
# Scores: (min: 103, avg: 139.11, max: 181)
#
# Run: 201, exploration: 0.01, score: 124
# Scores: (min: 103, avg: 139.17, max: 181)
#
# Run: 202, exploration: 0.01, score: 137
# Scores: (min: 103, avg: 139.37, max: 181)
#
# Run: 203, exploration: 0.01, score: 155
# Scores: (min: 103, avg: 139.7, max: 181)
#
# Run: 204, exploration: 0.01, score: 160
# Scores: (min: 103, avg: 139.81, max: 181)
#
# Run: 205, exploration: 0.01, score: 139
# Scores: (min: 116, avg: 140.17, max: 181)
#
# Run: 206, exploration: 0.01, score: 130
# Scores: (min: 116, avg: 139.85, max: 181)
#
# Run: 207, exploration: 0.01, score: 134
# Scores: (min: 116, avg: 139.81, max: 181)
#
# Run: 208, exploration: 0.01, score: 138
# Scores: (min: 116, avg: 139.77, max: 181)
#
# Run: 209, exploration: 0.01, score: 152
# Scores: (min: 116, avg: 139.78, max: 181)
#
# Run: 210, exploration: 0.01, score: 141
# Scores: (min: 116, avg: 139.93, max: 181)
#
# Run: 211, exploration: 0.01, score: 168
# Scores: (min: 116, avg: 140.29, max: 181)
#
# Run: 212, exploration: 0.01, score: 128
# Scores: (min: 116, avg: 140.24, max: 181)
#
# Run: 213, exploration: 0.01, score: 122
# Scores: (min: 116, avg: 139.95, max: 181)
#
# Run: 214, exploration: 0.01, score: 136
# Scores: (min: 116, avg: 139.9, max: 181)
#
# Run: 215, exploration: 0.01, score: 136
# Scores: (min: 116, avg: 140.01, max: 181)
#
# Run: 216, exploration: 0.01, score: 125
# Scores: (min: 116, avg: 139.87, max: 181)
#
# Run: 217, exploration: 0.01, score: 152
# Scores: (min: 116, avg: 140.1, max: 181)
#
# Run: 218, exploration: 0.01, score: 133
# Scores: (min: 116, avg: 139.96, max: 181)
#
# Run: 219, exploration: 0.01, score: 131
# Scores: (min: 116, avg: 139.87, max: 181)
#
# Run: 220, exploration: 0.01, score: 130
# Scores: (min: 116, avg: 139.88, max: 181)
#
# Run: 221, exploration: 0.01, score: 150
# Scores: (min: 116, avg: 140.09, max: 181)
#
# Run: 222, exploration: 0.01, score: 144
# Scores: (min: 116, avg: 140.1, max: 181)
#
# Run: 223, exploration: 0.01, score: 120
# Scores: (min: 116, avg: 139.89, max: 181)
#
# Run: 224, exploration: 0.01, score: 117
# Scores: (min: 116, avg: 139.71, max: 181)
#
# Run: 225, exploration: 0.01, score: 109
# Scores: (min: 109, avg: 139.32, max: 181)
#
# Run: 226, exploration: 0.01, score: 149
# Scores: (min: 109, avg: 139.37, max: 181)
#
# Run: 227, exploration: 0.01, score: 171
# Scores: (min: 109, avg: 139.92, max: 181)
#
# Run: 228, exploration: 0.01, score: 154
# Scores: (min: 109, avg: 140.09, max: 181)
#
# Run: 229, exploration: 0.01, score: 155
# Scores: (min: 109, avg: 140.3, max: 181)
#
# Run: 230, exploration: 0.01, score: 124
# Scores: (min: 109, avg: 140.21, max: 181)
#
# Run: 231, exploration: 0.01, score: 147
# Scores: (min: 109, avg: 140.32, max: 181)
#
# Run: 232, exploration: 0.01, score: 139
# Scores: (min: 109, avg: 140.29, max: 181)
#
# Run: 233, exploration: 0.01, score: 125
# Scores: (min: 109, avg: 140.15, max: 181)
#
# Run: 234, exploration: 0.01, score: 145
# Scores: (min: 109, avg: 140.27, max: 181)
#
# Run: 235, exploration: 0.01, score: 131
# Scores: (min: 109, avg: 140.16, max: 181)
#
# Run: 236, exploration: 0.01, score: 165
# Scores: (min: 109, avg: 140.31, max: 181)
#
# Run: 237, exploration: 0.01, score: 153
# Scores: (min: 109, avg: 140.4, max: 181)
#
# Run: 238, exploration: 0.01, score: 125
# Scores: (min: 109, avg: 140.33, max: 181)
#
# Run: 239, exploration: 0.01, score: 134
# Scores: (min: 109, avg: 140.34, max: 181)
#
# Run: 240, exploration: 0.01, score: 153
# Scores: (min: 109, avg: 140.56, max: 181)
#
# Run: 241, exploration: 0.01, score: 118
# Scores: (min: 109, avg: 140.34, max: 181)
#
# Run: 242, exploration: 0.01, score: 148
# Scores: (min: 109, avg: 140.42, max: 181)
#
# Run: 243, exploration: 0.01, score: 145
# Scores: (min: 109, avg: 140.47, max: 181)
#
# Run: 244, exploration: 0.01, score: 120
# Scores: (min: 109, avg: 140.45, max: 181)
#
# Run: 245, exploration: 0.01, score: 147
# Scores: (min: 109, avg: 140.59, max: 181)
#
# Run: 246, exploration: 0.01, score: 140
# Scores: (min: 109, avg: 140.49, max: 181)
#
# Run: 247, exploration: 0.01, score: 141
# Scores: (min: 109, avg: 140.56, max: 181)
#
# Run: 248, exploration: 0.01, score: 116
# Scores: (min: 109, avg: 140.28, max: 181)
#
# Run: 249, exploration: 0.01, score: 128
# Scores: (min: 109, avg: 140.22, max: 181)
#
# Run: 250, exploration: 0.01, score: 158
# Scores: (min: 109, avg: 140.6, max: 181)
#
# Run: 251, exploration: 0.01, score: 147
# Scores: (min: 109, avg: 140.64, max: 181)
#
# Run: 252, exploration: 0.01, score: 138
# Scores: (min: 109, avg: 140.64, max: 181)
#
# Run: 253, exploration: 0.01, score: 138
# Scores: (min: 109, avg: 140.58, max: 181)
#
# Run: 254, exploration: 0.01, score: 124
# Scores: (min: 109, avg: 140.45, max: 181)
#
# Run: 255, exploration: 0.01, score: 135
# Scores: (min: 109, avg: 140.23, max: 181)
#
# Run: 256, exploration: 0.01, score: 163
# Scores: (min: 109, avg: 140.44, max: 181)
#
# Run: 257, exploration: 0.01, score: 121
# Scores: (min: 109, avg: 140.29, max: 181)
#
# Run: 258, exploration: 0.01, score: 125
# Scores: (min: 109, avg: 139.92, max: 181)
#
# Run: 259, exploration: 0.01, score: 116
# Scores: (min: 109, avg: 139.79, max: 181)
#
# Run: 260, exploration: 0.01, score: 158
# Scores: (min: 109, avg: 140.01, max: 181)
#
# Run: 261, exploration: 0.01, score: 177
# Scores: (min: 109, avg: 140.54, max: 181)
#
# Run: 262, exploration: 0.01, score: 145
# Scores: (min: 109, avg: 140.73, max: 181)
#
# Run: 263, exploration: 0.01, score: 164
# Scores: (min: 109, avg: 140.94, max: 181)
#
# Run: 264, exploration: 0.01, score: 196
# Scores: (min: 109, avg: 141.46, max: 196)
#
# Run: 265, exploration: 0.01, score: 146
# Scores: (min: 109, avg: 141.69, max: 196)
#
# Run: 266, exploration: 0.01, score: 123
# Scores: (min: 109, avg: 141.18, max: 196)
#
# Run: 267, exploration: 0.01, score: 129
# Scores: (min: 109, avg: 141.19, max: 196)
#
# Run: 268, exploration: 0.01, score: 127
# Scores: (min: 109, avg: 140.97, max: 196)
#
# Run: 269, exploration: 0.01, score: 143
# Scores: (min: 109, avg: 141.09, max: 196)
#
# Run: 270, exploration: 0.01, score: 173
# Scores: (min: 109, avg: 141.22, max: 196)
#
# Run: 271, exploration: 0.01, score: 149
# Scores: (min: 109, avg: 141.37, max: 196)
#
# Run: 272, exploration: 0.01, score: 115
# Scores: (min: 109, avg: 140.94, max: 196)
#
# Run: 273, exploration: 0.01, score: 133
# Scores: (min: 109, avg: 140.9, max: 196)
#
# Run: 274, exploration: 0.01, score: 137
# Scores: (min: 109, avg: 140.78, max: 196)
#
# Run: 275, exploration: 0.01, score: 58
# Scores: (min: 58, avg: 139.79, max: 196)
#
# Run: 276, exploration: 0.01, score: 122
# Scores: (min: 58, avg: 139.65, max: 196)
#
# Run: 277, exploration: 0.01, score: 204
# Scores: (min: 58, avg: 140.26, max: 204)
#
# Run: 278, exploration: 0.01, score: 194
# Scores: (min: 58, avg: 140.76, max: 204)
#
# Run: 279, exploration: 0.01, score: 139
# Scores: (min: 58, avg: 140.63, max: 204)
#
# Run: 280, exploration: 0.01, score: 138
# Scores: (min: 58, avg: 140.31, max: 204)
#
# Run: 281, exploration: 0.01, score: 129
# Scores: (min: 58, avg: 140.17, max: 204)
#
# Run: 282, exploration: 0.01, score: 137
# Scores: (min: 58, avg: 140.22, max: 204)
#
# Run: 283, exploration: 0.01, score: 120
# Scores: (min: 58, avg: 139.93, max: 204)
#
# Run: 284, exploration: 0.01, score: 155
# Scores: (min: 58, avg: 140, max: 204)
#
# Run: 285, exploration: 0.01, score: 135
# Scores: (min: 58, avg: 140.03, max: 204)
#
# Run: 286, exploration: 0.01, score: 149
# Scores: (min: 58, avg: 140.28, max: 204)
#
# Run: 287, exploration: 0.01, score: 120
# Scores: (min: 58, avg: 140.17, max: 204)
#
# Run: 288, exploration: 0.01, score: 114
# Scores: (min: 58, avg: 139.85, max: 204)
# Run: 289, exploration: 0.01, score: 139
# Scores: (min: 58, avg: 139.99, max: 204)
#
# Run: 290, exploration: 0.01, score: 150
# Scores: (min: 58, avg: 139.68, max: 204)
#
# Run: 291, exploration: 0.01, score: 141
# Scores: (min: 58, avg: 139.83, max: 204)
#
# Run: 292, exploration: 0.01, score: 88
# Scores: (min: 58, avg: 139.32, max: 204)
#
# Run: 293, exploration: 0.01, score: 132
# Scores: (min: 58, avg: 139.27, max: 204)
#
# Run: 294, exploration: 0.01, score: 120
# Scores: (min: 58, avg: 138.81, max: 204)
#
# Run: 295, exploration: 0.01, score: 166
# Scores: (min: 58, avg: 139.26, max: 204)
#
# Run: 296, exploration: 0.01, score: 122
# Scores: (min: 58, avg: 139.15, max: 204)
#
# Run: 297, exploration: 0.01, score: 144
# Scores: (min: 58, avg: 139.08, max: 204)
#
# Run: 298, exploration: 0.01, score: 131
# Scores: (min: 58, avg: 138.99, max: 204)
#
# Run: 299, exploration: 0.01, score: 137
# Scores: (min: 58, avg: 138.89, max: 204)
#
# Run: 300, exploration: 0.01, score: 139
# Scores: (min: 58, avg: 138.87, max: 204)
#
# Run: 301, exploration: 0.01, score: 121
# Scores: (min: 58, avg: 138.84, max: 204)
#
# Run: 302, exploration: 0.01, score: 119
# Scores: (min: 58, avg: 138.66, max: 204)
#
# Run: 303, exploration: 0.01, score: 139
# Scores: (min: 58, avg: 138.5, max: 204)
#
# Run: 304, exploration: 0.01, score: 120
# Scores: (min: 58, avg: 138.1, max: 204)
#
# Run: 305, exploration: 0.01, score: 143
# Scores: (min: 58, avg: 138.14, max: 204)
#
# Run: 306, exploration: 0.01, score: 148
# Scores: (min: 58, avg: 138.32, max: 204)
#
# Run: 307, exploration: 0.01, score: 154
# Scores: (min: 58, avg: 138.52, max: 204)
#
# Run: 308, exploration: 0.01, score: 154
# Scores: (min: 58, avg: 138.68, max: 204)
#
# Run: 309, exploration: 0.01, score: 133
# Scores: (min: 58, avg: 138.49, max: 204)
#
# Run: 310, exploration: 0.01, score: 166
# Scores: (min: 58, avg: 138.74, max: 204)
#
# Run: 311, exploration: 0.01, score: 171
# Scores: (min: 58, avg: 138.77, max: 204)
#
# Run: 312, exploration: 0.01, score: 130
# Scores: (min: 58, avg: 138.79, max: 204)
#
# Run: 313, exploration: 0.01, score: 126
# Scores: (min: 58, avg: 138.83, max: 204)
#
# Run: 314, exploration: 0.01, score: 139
# Scores: (min: 58, avg: 138.86, max: 204)
#
# Run: 315, exploration: 0.01, score: 122
# Scores: (min: 58, avg: 138.72, max: 204)
#
# Run: 316, exploration: 0.01, score: 153
# Scores: (min: 58, avg: 139, max: 204)
#
# Run: 317, exploration: 0.01, score: 128
# Scores: (min: 58, avg: 138.76, max: 204)
#
# Run: 318, exploration: 0.01, score: 119
# Scores: (min: 58, avg: 138.62, max: 204)
#
# Run: 319, exploration: 0.01, score: 123
# Scores: (min: 58, avg: 138.54, max: 204)
#
# Run: 320, exploration: 0.01, score: 122
# Scores: (min: 58, avg: 138.46, max: 204)
#
# Run: 321, exploration: 0.01, score: 125
# Scores: (min: 58, avg: 138.21, max: 204)
#
# Run: 322, exploration: 0.01, score: 122
# Scores: (min: 58, avg: 137.99, max: 204)
#
# Run: 323, exploration: 0.01, score: 198
# Scores: (min: 58, avg: 138.77, max: 204)
#
# Run: 324, exploration: 0.01, score: 130
# Scores: (min: 58, avg: 138.9, max: 204)
#
# Run: 325, exploration: 0.01, score: 126
# Scores: (min: 58, avg: 139.07, max: 204)
#
# Run: 326, exploration: 0.01, score: 129
# Scores: (min: 58, avg: 138.87, max: 204)
#
# Run: 327, exploration: 0.01, score: 126
# Scores: (min: 58, avg: 138.42, max: 204)
#
# Run: 328, exploration: 0.01, score: 120
# Scores: (min: 58, avg: 138.08, max: 204)
#
# Run: 329, exploration: 0.01, score: 118
# Scores: (min: 58, avg: 137.71, max: 204)
#
# Run: 330, exploration: 0.01, score: 126
# Scores: (min: 58, avg: 137.73, max: 204)
#
# Run: 331, exploration: 0.01, score: 172
# Scores: (min: 58, avg: 137.98, max: 204)
#
# Run: 332, exploration: 0.01, score: 119
# Scores: (min: 58, avg: 137.78, max: 204)
#
# Run: 333, exploration: 0.01, score: 115
# Scores: (min: 58, avg: 137.68, max: 204)
#
# Run: 334, exploration: 0.01, score: 132
# Scores: (min: 58, avg: 137.55, max: 204)
#
# Run: 335, exploration: 0.01, score: 143
# Scores: (min: 58, avg: 137.67, max: 204)
#
# Run: 336, exploration: 0.01, score: 116
# Scores: (min: 58, avg: 137.18, max: 204)
#
# Run: 337, exploration: 0.01, score: 165
# Scores: (min: 58, avg: 137.3, max: 204)
#
# Run: 338, exploration: 0.01, score: 128
# Scores: (min: 58, avg: 137.33, max: 204)
#
# Run: 339, exploration: 0.01, score: 118
# Scores: (min: 58, avg: 137.17, max: 204)
#
# Run: 340, exploration: 0.01, score: 86
# Scores: (min: 58, avg: 136.5, max: 204)
#
# Run: 341, exploration: 0.01, score: 131
# Scores: (min: 58, avg: 136.63, max: 204)
#
# Run: 342, exploration: 0.01, score: 192
# Scores: (min: 58, avg: 137.07, max: 204)
#
# Run: 343, exploration: 0.01, score: 143
# Scores: (min: 58, avg: 137.05, max: 204)
#
# Run: 344, exploration: 0.01, score: 126
# Scores: (min: 58, avg: 137.11, max: 204)
#
# Run: 345, exploration: 0.01, score: 120
# Scores: (min: 58, avg: 136.84, max: 204)
#
# Run: 346, exploration: 0.01, score: 120
# Scores: (min: 58, avg: 136.64, max: 204)
#
# Run: 347, exploration: 0.01, score: 146
# Scores: (min: 58, avg: 136.69, max: 204)
#
# Run: 348, exploration: 0.01, score: 131
# Scores: (min: 58, avg: 136.84, max: 204)
#
# Run: 349, exploration: 0.01, score: 130
# Scores: (min: 58, avg: 136.86, max: 204)
#
# Run: 350, exploration: 0.01, score: 165
# Scores: (min: 58, avg: 136.93, max: 204)
#
# Run: 351, exploration: 0.01, score: 139
# Scores: (min: 58, avg: 136.85, max: 204)
#
# Run: 352, exploration: 0.01, score: 146
# Scores: (min: 58, avg: 136.93, max: 204)
#
# Run: 353, exploration: 0.01, score: 125
# Scores: (min: 58, avg: 136.8, max: 204)
#
# Run: 354, exploration: 0.01, score: 129
# Scores: (min: 58, avg: 136.85, max: 204)
#
# Run: 355, exploration: 0.01, score: 134
# Scores: (min: 58, avg: 136.84, max: 204)
#
# Run: 356, exploration: 0.01, score: 125
# Scores: (min: 58, avg: 136.46, max: 204)
#
# Run: 357, exploration: 0.01, score: 213
# Scores: (min: 58, avg: 137.38, max: 213)
#
# Run: 358, exploration: 0.01, score: 120
# Scores: (min: 58, avg: 137.33, max: 213)
#
# Run: 359, exploration: 0.01, score: 162
# Scores: (min: 58, avg: 137.79, max: 213)
#
# Run: 360, exploration: 0.01, score: 132
# Scores: (min: 58, avg: 137.53, max: 213)
#
# Run: 361, exploration: 0.01, score: 131
# Scores: (min: 58, avg: 137.07, max: 213)
#
# Run: 362, exploration: 0.01, score: 70
# Scores: (min: 58, avg: 136.32, max: 213)
#
# Run: 363, exploration: 0.01, score: 168
# Scores: (min: 58, avg: 136.36, max: 213)
#
# Run: 364, exploration: 0.01, score: 140
# Scores: (min: 58, avg: 135.8, max: 213)
#
# Run: 365, exploration: 0.01, score: 121
# Scores: (min: 58, avg: 135.55, max: 213)
#
# Run: 366, exploration: 0.01, score: 100
# Scores: (min: 58, avg: 135.32, max: 213)
#
# Run: 367, exploration: 0.01, score: 107
# Scores: (min: 58, avg: 135.1, max: 213)
#
# Run: 368, exploration: 0.01, score: 268
# Scores: (min: 58, avg: 136.51, max: 268)
#
# Run: 369, exploration: 0.01, score: 133
# Scores: (min: 58, avg: 136.41, max: 268)
#
# Run: 370, exploration: 0.01, score: 151
# Scores: (min: 58, avg: 136.19, max: 268)
#
# Run: 371, exploration: 0.01, score: 140
# Scores: (min: 58, avg: 136.1, max: 268)
#
# Run: 372, exploration: 0.01, score: 71
# Scores: (min: 58, avg: 135.66, max: 268)
#
# Run: 373, exploration: 0.01, score: 204
# Scores: (min: 58, avg: 136.37, max: 268)
#
# Run: 374, exploration: 0.01, score: 131
# Scores: (min: 58, avg: 136.31, max: 268)
#
# Run: 375, exploration: 0.01, score: 150
# Scores: (min: 70, avg: 137.23, max: 268)
#
# Run: 376, exploration: 0.01, score: 115
# Scores: (min: 70, avg: 137.16, max: 268)
#
# Run: 377, exploration: 0.01, score: 63
# Scores: (min: 63, avg: 135.75, max: 268)
#
# Run: 378, exploration: 0.01, score: 160
# Scores: (min: 63, avg: 135.41, max: 268)
#
# Run: 379, exploration: 0.01, score: 133
# Scores: (min: 63, avg: 135.35, max: 268)
#
# Run: 380, exploration: 0.01, score: 132
# Scores: (min: 63, avg: 135.29, max: 268)
#
# Run: 381, exploration: 0.01, score: 79
# Scores: (min: 63, avg: 134.79, max: 268)
#
# Run: 382, exploration: 0.01, score: 68
# Scores: (min: 63, avg: 134.1, max: 268)
#
# Run: 383, exploration: 0.01, score: 90
# Scores: (min: 63, avg: 133.8, max: 268)
#
# Run: 384, exploration: 0.01, score: 108
# Scores: (min: 63, avg: 133.33, max: 268)
#
# Run: 385, exploration: 0.01, score: 129
# Scores: (min: 63, avg: 133.27, max: 268)
#
# Run: 386, exploration: 0.01, score: 135
# Scores: (min: 63, avg: 133.13, max: 268)
#
# Run: 387, exploration: 0.01, score: 152
# Scores: (min: 63, avg: 133.45, max: 268)
#
# Run: 388, exploration: 0.01, score: 13
# Scores: (min: 13, avg: 132.44, max: 268)
#
# Run: 389, exploration: 0.01, score: 152
# Scores: (min: 13, avg: 132.57, max: 268)
# Run: 390, exploration: 0.01, score: 109
# Scores: (min: 13, avg: 132.16, max: 268)
#
# Run: 391, exploration: 0.01, score: 88
# Scores: (min: 13, avg: 131.63, max: 268)
#
# Run: 392, exploration: 0.01, score: 81
# Scores: (min: 13, avg: 131.56, max: 268)
#
# Run: 393, exploration: 0.01, score: 66
# Scores: (min: 13, avg: 130.9, max: 268)
#
# Run: 394, exploration: 0.01, score: 117
# Scores: (min: 13, avg: 130.87, max: 268)
#
# Run: 395, exploration: 0.01, score: 114
# Scores: (min: 13, avg: 130.35, max: 268)
#
# Run: 396, exploration: 0.01, score: 97
# Scores: (min: 13, avg: 130.1, max: 268)
#
# Run: 397, exploration: 0.01, score: 103
# Scores: (min: 13, avg: 129.69, max: 268)
#
# Run: 398, exploration: 0.01, score: 112
# Scores: (min: 13, avg: 129.5, max: 268)
#
# Run: 399, exploration: 0.01, score: 148
# Scores: (min: 13, avg: 129.61, max: 268)
#
# Run: 400, exploration: 0.01, score: 131
# Scores: (min: 13, avg: 129.53, max: 268)
#
# Run: 401, exploration: 0.01, score: 112
# Scores: (min: 13, avg: 129.44, max: 268)
#
# Run: 402, exploration: 0.01, score: 130
# Scores: (min: 13, avg: 129.55, max: 268)
#
# Run: 403, exploration: 0.01, score: 139
# Scores: (min: 13, avg: 129.55, max: 268)
#
# Run: 404, exploration: 0.01, score: 166
# Scores: (min: 13, avg: 130.01, max: 268)
#
# Run: 405, exploration: 0.01, score: 103
# Scores: (min: 13, avg: 129.61, max: 268)
#
# Run: 406, exploration: 0.01, score: 63
# Scores: (min: 13, avg: 128.76, max: 268)
#
# Run: 407, exploration: 0.01, score: 101
# Scores: (min: 13, avg: 128.23, max: 268)
#
# Run: 408, exploration: 0.01, score: 86
# Scores: (min: 13, avg: 127.55, max: 268)
#
# Run: 409, exploration: 0.01, score: 12
# Scores: (min: 12, avg: 126.34, max: 268)
#
# Run: 410, exploration: 0.01, score: 100
# Scores: (min: 12, avg: 125.68, max: 268)
#
# Run: 411, exploration: 0.01, score: 68
# Scores: (min: 12, avg: 124.65, max: 268)
#
# Run: 412, exploration: 0.01, score: 104
# Scores: (min: 12, avg: 124.39, max: 268)
#
# Run: 413, exploration: 0.01, score: 15
# Scores: (min: 12, avg: 123.28, max: 268)
#
# Run: 414, exploration: 0.01, score: 67
# Scores: (min: 12, avg: 122.56, max: 268)
#
# Run: 415, exploration: 0.01, score: 82
# Scores: (min: 12, avg: 122.16, max: 268)
#
# Run: 416, exploration: 0.01, score: 92
# Scores: (min: 12, avg: 121.55, max: 268)
#
# Run: 417, exploration: 0.01, score: 101
# Scores: (min: 12, avg: 121.28, max: 268)
#
# Run: 418, exploration: 0.01, score: 74
# Scores: (min: 12, avg: 120.83, max: 268)
#
# Run: 419, exploration: 0.01, score: 366
# Scores: (min: 12, avg: 123.26, max: 366)
#
# Run: 420, exploration: 0.01, score: 121
# Scores: (min: 12, avg: 123.25, max: 366)
#
# Run: 421, exploration: 0.01, score: 129
# Scores: (min: 12, avg: 123.29, max: 366)
#
# Run: 422, exploration: 0.01, score: 86
# Scores: (min: 12, avg: 122.93, max: 366)
#
# Run: 423, exploration: 0.01, score: 109
# Scores: (min: 12, avg: 122.04, max: 366)
#
# Run: 424, exploration: 0.01, score: 115
# Scores: (min: 12, avg: 121.89, max: 366)
#
# Run: 425, exploration: 0.01, score: 81
# Scores: (min: 12, avg: 121.44, max: 366)
#
# Run: 426, exploration: 0.01, score: 115
# Scores: (min: 12, avg: 121.3, max: 366)
#
# Run: 427, exploration: 0.01, score: 117
# Scores: (min: 12, avg: 121.21, max: 366)
#
# Run: 428, exploration: 0.01, score: 86
# Scores: (min: 12, avg: 120.87, max: 366)
#
# Run: 429, exploration: 0.01, score: 89
# Scores: (min: 12, avg: 120.58, max: 366)
#
# Run: 430, exploration: 0.01, score: 79
# Scores: (min: 12, avg: 120.11, max: 366)
#
# Run: 431, exploration: 0.01, score: 119
# Scores: (min: 12, avg: 119.58, max: 366)
#
# Run: 432, exploration: 0.01, score: 218
# Scores: (min: 12, avg: 120.57, max: 366)
#
# Run: 433, exploration: 0.01, score: 111
# Scores: (min: 12, avg: 120.53, max: 366)
#
# Run: 434, exploration: 0.01, score: 125
# Scores: (min: 12, avg: 120.46, max: 366)
#
# Run: 435, exploration: 0.01, score: 153
# Scores: (min: 12, avg: 120.56, max: 366)
#
# Run: 436, exploration: 0.01, score: 131
# Scores: (min: 12, avg: 120.71, max: 366)
#
# Run: 437, exploration: 0.01, score: 136
# Scores: (min: 12, avg: 120.42, max: 366)
#
# Run: 438, exploration: 0.01, score: 31
# Scores: (min: 12, avg: 119.45, max: 366)
#
# Run: 439, exploration: 0.01, score: 80
# Scores: (min: 12, avg: 119.07, max: 366)
#
# Run: 440, exploration: 0.01, score: 103
# Scores: (min: 12, avg: 119.24, max: 366)
#
# Run: 441, exploration: 0.01, score: 121
# Scores: (min: 12, avg: 119.14, max: 366)
#
# Run: 442, exploration: 0.01, score: 99
# Scores: (min: 12, avg: 118.21, max: 366)
#
# Run: 443, exploration: 0.01, score: 116
# Scores: (min: 12, avg: 117.94, max: 366)
#
# Run: 444, exploration: 0.01, score: 92
# Scores: (min: 12, avg: 117.6, max: 366)
#
# Run: 445, exploration: 0.01, score: 129
# Scores: (min: 12, avg: 117.69, max: 366)
#
# Run: 446, exploration: 0.01, score: 124
# Scores: (min: 12, avg: 117.73, max: 366)
#
# Run: 447, exploration: 0.01, score: 121
# Scores: (min: 12, avg: 117.48, max: 366)
#
# Run: 448, exploration: 0.01, score: 160
# Scores: (min: 12, avg: 117.77, max: 366)
#
# Run: 449, exploration: 0.01, score: 131
# Scores: (min: 12, avg: 117.78, max: 366)
#
# Run: 450, exploration: 0.01, score: 146
# Scores: (min: 12, avg: 117.59, max: 366)
#
# Run: 451, exploration: 0.01, score: 117
# Scores: (min: 12, avg: 117.37, max: 366)
#
# Run: 452, exploration: 0.01, score: 152
# Scores: (min: 12, avg: 117.43, max: 366)
#
# Run: 453, exploration: 0.01, score: 60
# Scores: (min: 12, avg: 116.78, max: 366)
#
# Run: 454, exploration: 0.01, score: 166
# Scores: (min: 12, avg: 117.15, max: 366)
#
# Run: 455, exploration: 0.01, score: 139
# Scores: (min: 12, avg: 117.2, max: 366)
#
# Run: 456, exploration: 0.01, score: 130
# Scores: (min: 12, avg: 117.25, max: 366)
#
# Run: 457, exploration: 0.01, score: 92
# Scores: (min: 12, avg: 116.04, max: 366)
#
# Run: 458, exploration: 0.01, score: 132
# Scores: (min: 12, avg: 116.16, max: 366)
#
# Run: 459, exploration: 0.01, score: 216
# Scores: (min: 12, avg: 116.7, max: 366)
#
# Run: 460, exploration: 0.01, score: 231
# Scores: (min: 12, avg: 117.69, max: 366)
#
# Run: 461, exploration: 0.01, score: 117
# Scores: (min: 12, avg: 117.55, max: 366)
#
# Run: 462, exploration: 0.01, score: 116
# Scores: (min: 12, avg: 118.01, max: 366)
#
# Run: 463, exploration: 0.01, score: 127
# Scores: (min: 12, avg: 117.6, max: 366)
#
# Run: 464, exploration: 0.01, score: 156
# Scores: (min: 12, avg: 117.76, max: 366)
#
# Run: 465, exploration: 0.01, score: 111
# Scores: (min: 12, avg: 117.66, max: 366)
#
# Run: 466, exploration: 0.01, score: 120
# Scores: (min: 12, avg: 117.86, max: 366)
#
# Run: 467, exploration: 0.01, score: 169
# Scores: (min: 12, avg: 118.48, max: 366)
#
# Run: 468, exploration: 0.01, score: 187
# Scores: (min: 12, avg: 117.67, max: 366)
#
# Run: 469, exploration: 0.01, score: 126
# Scores: (min: 12, avg: 117.6, max: 366)
#
# Run: 470, exploration: 0.01, score: 240
# Scores: (min: 12, avg: 118.49, max: 366)
#
# Run: 471, exploration: 0.01, score: 148
# Scores: (min: 12, avg: 118.57, max: 366)
#
# Run: 472, exploration: 0.01, score: 107
# Scores: (min: 12, avg: 118.93, max: 366)
#
# Run: 473, exploration: 0.01, score: 130
# Scores: (min: 12, avg: 118.19, max: 366)
#
# Run: 474, exploration: 0.01, score: 116
# Scores: (min: 12, avg: 118.04, max: 366)
#
# Run: 475, exploration: 0.01, score: 121
# Scores: (min: 12, avg: 117.75, max: 366)
#
# Run: 476, exploration: 0.01, score: 302
# Scores: (min: 12, avg: 119.62, max: 366)
#
# Run: 477, exploration: 0.01, score: 125
# Scores: (min: 12, avg: 120.24, max: 366)
#
# Run: 478, exploration: 0.01, score: 111
# Scores: (min: 12, avg: 119.75, max: 366)
#
# Run: 479, exploration: 0.01, score: 287
# Scores: (min: 12, avg: 121.29, max: 366)
#
# Run: 480, exploration: 0.01, score: 139
# Scores: (min: 12, avg: 121.36, max: 366)
#
# Run: 481, exploration: 0.01, score: 125
# Scores: (min: 12, avg: 121.82, max: 366)
#
# Run: 482, exploration: 0.01, score: 186
# Scores: (min: 12, avg: 123, max: 366)
#
# Run: 483, exploration: 0.01, score: 126
# Scores: (min: 12, avg: 123.36, max: 366)
#
# Run: 484, exploration: 0.01, score: 29
# Scores: (min: 12, avg: 122.57, max: 366)
#
# Run: 485, exploration: 0.01, score: 160
# Scores: (min: 12, avg: 122.88, max: 366)
#
# Run: 486, exploration: 0.01, score: 83
# Scores: (min: 12, avg: 122.36, max: 366)
#
# Run: 487, exploration: 0.01, score: 194
# Scores: (min: 12, avg: 122.78, max: 366)
#
# Run: 488, exploration: 0.01, score: 145
# Scores: (min: 12, avg: 124.1, max: 366)
#
# Run: 489, exploration: 0.01, score: 134
# Scores: (min: 12, avg: 123.92, max: 366)
#
# Run: 490, exploration: 0.01, score: 170
# Scores: (min: 12, avg: 124.53, max: 366)
# Run: 491, exploration: 0.01, score: 39
# Scores: (min: 12, avg: 124.04, max: 366)
#
# Run: 492, exploration: 0.01, score: 53
# Scores: (min: 12, avg: 123.76, max: 366)
#
# Run: 493, exploration: 0.01, score: 98
# Scores: (min: 12, avg: 124.08, max: 366)
#
# Run: 494, exploration: 0.01, score: 117
# Scores: (min: 12, avg: 124.08, max: 366)
#
# Run: 495, exploration: 0.01, score: 106
# Scores: (min: 12, avg: 124, max: 366)
#
# Run: 496, exploration: 0.01, score: 128
# Scores: (min: 12, avg: 124.31, max: 366)
#
# Run: 497, exploration: 0.01, score: 140
# Scores: (min: 12, avg: 124.68, max: 366)
#
# Run: 498, exploration: 0.01, score: 113
# Scores: (min: 12, avg: 124.69, max: 366)
#
# Run: 499, exploration: 0.01, score: 189
# Scores: (min: 12, avg: 125.1, max: 366)
#
# Run: 500, exploration: 0.01, score: 121
# Scores: (min: 12, avg: 125, max: 366)
#
# Run: 501, exploration: 0.01, score: 100
# Scores: (min: 12, avg: 124.88, max: 366)
#
# Run: 502, exploration: 0.01, score: 145
# Scores: (min: 12, avg: 125.03, max: 366)
#
# Run: 503, exploration: 0.01, score: 171
# Scores: (min: 12, avg: 125.35, max: 366)
#
# Run: 504, exploration: 0.01, score: 12
# Scores: (min: 12, avg: 123.81, max: 366)
#
# Run: 505, exploration: 0.01, score: 86
# Scores: (min: 12, avg: 123.64, max: 366)
#
# Run: 506, exploration: 0.01, score: 114
# Scores: (min: 12, avg: 124.15, max: 366)
#
# Run: 507, exploration: 0.01, score: 137
# Scores: (min: 12, avg: 124.51, max: 366)
#
# Run: 508, exploration: 0.01, score: 111
# Scores: (min: 12, avg: 124.76, max: 366)
#
# Run: 509, exploration: 0.01, score: 116
# Scores: (min: 12, avg: 125.8, max: 366)
#
# Run: 510, exploration: 0.01, score: 167
# Scores: (min: 12, avg: 126.47, max: 366)
#
# Run: 511, exploration: 0.01, score: 333
# Scores: (min: 12, avg: 129.12, max: 366)
#
# Run: 512, exploration: 0.01, score: 111
# Scores: (min: 12, avg: 129.19, max: 366)
#
# Run: 513, exploration: 0.01, score: 134
# Scores: (min: 12, avg: 130.38, max: 366)
#
# Run: 514, exploration: 0.01, score: 136
# Scores: (min: 12, avg: 131.07, max: 366)
#
# Run: 515, exploration: 0.01, score: 105
# Scores: (min: 12, avg: 131.3, max: 366)
#
# Run: 516, exploration: 0.01, score: 118
# Scores: (min: 12, avg: 131.56, max: 366)
#
# Run: 517, exploration: 0.01, score: 253
# Scores: (min: 12, avg: 133.08, max: 366)
#
# Run: 518, exploration: 0.01, score: 114
# Scores: (min: 12, avg: 133.48, max: 366)
#
# Run: 519, exploration: 0.01, score: 120
# Scores: (min: 12, avg: 131.02, max: 333)
#
# Run: 520, exploration: 0.01, score: 116
# Scores: (min: 12, avg: 130.97, max: 333)
#
# Run: 521, exploration: 0.01, score: 129
# Scores: (min: 12, avg: 130.97, max: 333)
#
# Run: 522, exploration: 0.01, score: 185
# Scores: (min: 12, avg: 131.96, max: 333)
#
# Run: 523, exploration: 0.01, score: 31
# Scores: (min: 12, avg: 131.18, max: 333)
#
# Run: 524, exploration: 0.01, score: 23
# Scores: (min: 12, avg: 130.26, max: 333)
#
# Run: 525, exploration: 0.01, score: 15
# Scores: (min: 12, avg: 129.6, max: 333)
#
# Run: 526, exploration: 0.01, score: 123
# Scores: (min: 12, avg: 129.68, max: 333)
#
# Run: 527, exploration: 0.01, score: 147
# Scores: (min: 12, avg: 129.98, max: 333)
#
# Run: 528, exploration: 0.01, score: 130
# Scores: (min: 12, avg: 130.42, max: 333)
#
# Run: 529, exploration: 0.01, score: 125
# Scores: (min: 12, avg: 130.78, max: 333)
#
# Run: 530, exploration: 0.01, score: 128
# Scores: (min: 12, avg: 131.27, max: 333)
#
# Run: 531, exploration: 0.01, score: 144
# Scores: (min: 12, avg: 131.52, max: 333)
#
# Run: 532, exploration: 0.01, score: 111
# Scores: (min: 12, avg: 130.45, max: 333)
#
# Run: 533, exploration: 0.01, score: 135
# Scores: (min: 12, avg: 130.69, max: 333)
#
# Run: 534, exploration: 0.01, score: 108
# Scores: (min: 12, avg: 130.52, max: 333)
#
# Run: 535, exploration: 0.01, score: 98
# Scores: (min: 12, avg: 129.97, max: 333)
#
# Run: 536, exploration: 0.01, score: 108
# Scores: (min: 12, avg: 129.74, max: 333)
#
# Run: 537, exploration: 0.01, score: 104
# Scores: (min: 12, avg: 129.42, max: 333)
#
# Run: 538, exploration: 0.01, score: 122
# Scores: (min: 12, avg: 130.33, max: 333)
#
# Run: 539, exploration: 0.01, score: 128
# Scores: (min: 12, avg: 130.81, max: 333)
#
# Run: 540, exploration: 0.01, score: 112
# Scores: (min: 12, avg: 130.9, max: 333)
#
# Run: 541, exploration: 0.01, score: 119
# Scores: (min: 12, avg: 130.88, max: 333)
#
# Run: 542, exploration: 0.01, score: 130
# Scores: (min: 12, avg: 131.19, max: 333)
#
# Run: 543, exploration: 0.01, score: 194
# Scores: (min: 12, avg: 131.97, max: 333)
#
# Run: 544, exploration: 0.01, score: 117
# Scores: (min: 12, avg: 132.22, max: 333)
#
# Run: 545, exploration: 0.01, score: 164
# Scores: (min: 12, avg: 132.57, max: 333)
#
# Run: 546, exploration: 0.01, score: 153
# Scores: (min: 12, avg: 132.86, max: 333)
#
# Run: 547, exploration: 0.01, score: 135
# Scores: (min: 12, avg: 133, max: 333)
#
# Run: 548, exploration: 0.01, score: 153
# Scores: (min: 12, avg: 132.93, max: 333)
#
# Run: 549, exploration: 0.01, score: 103
# Scores: (min: 12, avg: 132.65, max: 333)
#
# Run: 550, exploration: 0.01, score: 115
# Scores: (min: 12, avg: 132.34, max: 333)
#
# Run: 551, exploration: 0.01, score: 169
# Scores: (min: 12, avg: 132.86, max: 333)
#
# Run: 552, exploration: 0.01, score: 111
# Scores: (min: 12, avg: 132.45, max: 333)
#
# Run: 553, exploration: 0.01, score: 243
# Scores: (min: 12, avg: 134.28, max: 333)
#
# Run: 554, exploration: 0.01, score: 252
# Scores: (min: 12, avg: 135.14, max: 333)
#
# Run: 555, exploration: 0.01, score: 130
# Scores: (min: 12, avg: 135.05, max: 333)
#
# Run: 556, exploration: 0.01, score: 116
# Scores: (min: 12, avg: 134.91, max: 333)
#
# Run: 557, exploration: 0.01, score: 126
# Scores: (min: 12, avg: 135.25, max: 333)
#
# Run: 558, exploration: 0.01, score: 138
# Scores: (min: 12, avg: 135.31, max: 333)
#
# Run: 559, exploration: 0.01, score: 189
# Scores: (min: 12, avg: 135.04, max: 333)
#
# Run: 560, exploration: 0.01, score: 146
# Scores: (min: 12, avg: 134.19, max: 333)
#
# Run: 561, exploration: 0.01, score: 142
# Scores: (min: 12, avg: 134.44, max: 333)
#
# Run: 562, exploration: 0.01, score: 173
# Scores: (min: 12, avg: 135.01, max: 333)
#
# Run: 563, exploration: 0.01, score: 203
# Scores: (min: 12, avg: 135.77, max: 333)
#
# Run: 564, exploration: 0.01, score: 113
# Scores: (min: 12, avg: 135.34, max: 333)
#
# Run: 565, exploration: 0.01, score: 171
# Scores: (min: 12, avg: 135.94, max: 333)
#
# Run: 566, exploration: 0.01, score: 135
# Scores: (min: 12, avg: 136.09, max: 333)
#
# Run: 567, exploration: 0.01, score: 149
# Scores: (min: 12, avg: 135.89, max: 333)
#
# Run: 568, exploration: 0.01, score: 129
# Scores: (min: 12, avg: 135.31, max: 333)
#
# Run: 569, exploration: 0.01, score: 142
# Scores: (min: 12, avg: 135.47, max: 333)
#
# Run: 570, exploration: 0.01, score: 175
# Scores: (min: 12, avg: 134.82, max: 333)
#
# Run: 571, exploration: 0.01, score: 153
# Scores: (min: 12, avg: 134.87, max: 333)
#
# Run: 572, exploration: 0.01, score: 127
# Scores: (min: 12, avg: 135.07, max: 333)
#
# Run: 573, exploration: 0.01, score: 188
# Scores: (min: 12, avg: 135.65, max: 333)
#
# ...
# Scores: (min: 47, avg: 158.62, max: 356)
#
# Run: 654, exploration: 0.01, score: 209
# Scores: (min: 47, avg: 158.19, max: 356)
#
# Run: 655, exploration: 0.01, score: 248
# Scores: (min: 47, avg: 159.37, max: 356)
#
# Run: 656, exploration: 0.01, score: 191
# Scores: (min: 47, avg: 160.12, max: 356)
#
# Run: 657, exploration: 0.01, score: 117
# Scores: (min: 47, avg: 160.03, max: 356)
#
# Run: 658, exploration: 0.01, score: 131
# Scores: (min: 47, avg: 159.96, max: 356)
#
# Run: 659, exploration: 0.01, score: 124
# Scores: (min: 47, avg: 159.31, max: 356)
#
# Run: 660, exploration: 0.01, score: 96
# Scores: (min: 47, avg: 158.81, max: 356)
#
# Run: 661, exploration: 0.01, score: 239
# Scores: (min: 47, avg: 159.78, max: 356)
#
# Run: 662, exploration: 0.01, score: 136
# Scores: (min: 47, avg: 159.41, max: 356)
#
# Run: 663, exploration: 0.01, score: 206
# Scores: (min: 47, avg: 159.44, max: 356)
#
# Run: 664, exploration: 0.01, score: 148
# Scores: (min: 47, avg: 159.79, max: 356)
#
# Run: 665, exploration: 0.01, score: 167
# Scores: (min: 47, avg: 159.75, max: 356)
#
# Run: 666, exploration: 0.01, score: 116
# Scores: (min: 47, avg: 159.56, max: 356)
#
# Run: 667, exploration: 0.01, score: 105
# Scores: (min: 47, avg: 159.12, max: 356)
#
# Run: 668, exploration: 0.01, score: 147
# Scores: (min: 47, avg: 159.3, max: 356)
#
# Run: 669, exploration: 0.01, score: 323
# Scores: (min: 47, avg: 161.11, max: 356)
#
# Run: 670, exploration: 0.01, score: 118
# Scores: (min: 47, avg: 160.54, max: 356)
#
# Run: 671, exploration: 0.01, score: 101
# Scores: (min: 47, avg: 160.02, max: 356)
#
# Run: 672, exploration: 0.01, score: 89
# Scores: (min: 47, avg: 159.64, max: 356)
#
# Run: 673, exploration: 0.01, score: 157
# Scores: (min: 47, avg: 159.33, max: 356)
#
# Run: 674, exploration: 0.01, score: 190
# Scores: (min: 47, avg: 159.85, max: 356)
#
# Run: 675, exploration: 0.01, score: 120
# Scores: (min: 47, avg: 159.23, max: 356)
#
# Run: 676, exploration: 0.01, score: 118
# Scores: (min: 47, avg: 159.2, max: 356)
#
# Run: 677, exploration: 0.01, score: 203
# Scores: (min: 47, avg: 160.01, max: 356)
#
# Run: 678, exploration: 0.01, score: 194
# Scores: (min: 47, avg: 160.43, max: 356)
#
# Run: 679, exploration: 0.01, score: 166
# Scores: (min: 47, avg: 160.46, max: 356)
#
# Run: 680, exploration: 0.01, score: 159
# Scores: (min: 47, avg: 160.37, max: 356)
#
# Run: 681, exploration: 0.01, score: 180
# Scores: (min: 47, avg: 161.01, max: 356)
#
# Run: 682, exploration: 0.01, score: 143
# Scores: (min: 47, avg: 158.88, max: 326)
#
# Run: 683, exploration: 0.01, score: 123
# Scores: (min: 47, avg: 158.84, max: 326)
#
# Run: 684, exploration: 0.01, score: 152
# Scores: (min: 47, avg: 157.1, max: 323)
#
# Run: 685, exploration: 0.01, score: 203
# Scores: (min: 47, avg: 158.07, max: 323)
#
# Run: 686, exploration: 0.01, score: 207
# Scores: (min: 47, avg: 159.16, max: 323)
#
# Run: 687, exploration: 0.01, score: 127
# Scores: (min: 47, avg: 159.28, max: 323)
#
# Run: 688, exploration: 0.01, score: 189
# Scores: (min: 47, avg: 160.16, max: 323)
#
# Run: 689, exploration: 0.01, score: 187
# Scores: (min: 47, avg: 160.86, max: 323)
#
# Run: 690, exploration: 0.01, score: 145
# Scores: (min: 47, avg: 160.14, max: 323)
#
# Run: 691, exploration: 0.01, score: 148
# Scores: (min: 47, avg: 160.3, max: 323)
#
# Run: 692, exploration: 0.01, score: 120
# Scores: (min: 47, avg: 160.1, max: 323)
# Run: 693, exploration: 0.01, score: 150
# Scores: (min: 47, avg: 159.96, max: 323)
#
# Run: 694, exploration: 0.01, score: 198
# Scores: (min: 47, avg: 160.75, max: 323)
#
# Run: 695, exploration: 0.01, score: 229
# Scores: (min: 47, avg: 161.82, max: 323)
#
# Run: 696, exploration: 0.01, score: 136
# Scores: (min: 47, avg: 161.68, max: 323)
#
# Run: 697, exploration: 0.01, score: 106
# Scores: (min: 47, avg: 161.78, max: 323)
#
# Run: 698, exploration: 0.01, score: 145
# Scores: (min: 47, avg: 161.95, max: 323)
#
# Run: 699, exploration: 0.01, score: 193
# Scores: (min: 47, avg: 161.99, max: 323)
#
# Run: 700, exploration: 0.01, score: 150
# Scores: (min: 47, avg: 162.17, max: 323)
#
# Run: 701, exploration: 0.01, score: 104
# Scores: (min: 47, avg: 162.12, max: 323)
#
# Run: 702, exploration: 0.01, score: 191
# Scores: (min: 47, avg: 162.59, max: 323)
#
# Run: 703, exploration: 0.01, score: 148
# Scores: (min: 47, avg: 162.47, max: 323)
#
# Run: 704, exploration: 0.01, score: 121
# Scores: (min: 47, avg: 161.17, max: 323)
#
# Run: 705, exploration: 0.01, score: 316
# Scores: (min: 47, avg: 163.01, max: 323)
#
# Run: 706, exploration: 0.01, score: 209
# Scores: (min: 47, avg: 163.79, max: 323)
#
# Run: 707, exploration: 0.01, score: 132
# Scores: (min: 47, avg: 163.94, max: 323)
#
# Run: 708, exploration: 0.01, score: 192
# Scores: (min: 47, avg: 164.27, max: 323)
#
# Run: 709, exploration: 0.01, score: 132
# Scores: (min: 47, avg: 164.17, max: 323)
#
# Run: 710, exploration: 0.01, score: 169
# Scores: (min: 47, avg: 163.64, max: 323)
#
# Run: 711, exploration: 0.01, score: 132
# Scores: (min: 47, avg: 162.69, max: 323)
#
# Run: 712, exploration: 0.01, score: 122
# Scores: (min: 47, avg: 162.19, max: 323)
#
# Run: 713, exploration: 0.01, score: 186
# Scores: (min: 47, avg: 162.61, max: 323)
#
# Run: 714, exploration: 0.01, score: 125
# Scores: (min: 47, avg: 162.62, max: 323)
#
# Run: 715, exploration: 0.01, score: 197
# Scores: (min: 47, avg: 162.3, max: 323)
#
# Run: 716, exploration: 0.01, score: 171
# Scores: (min: 47, avg: 162.53, max: 323)
#
# Run: 717, exploration: 0.01, score: 157
# Scores: (min: 47, avg: 162.55, max: 323)
#
# Run: 718, exploration: 0.01, score: 102
# Scores: (min: 47, avg: 161.27, max: 323)
#
# Run: 719, exploration: 0.01, score: 144
# Scores: (min: 47, avg: 161.21, max: 323)
#
# Run: 720, exploration: 0.01, score: 133
# Scores: (min: 47, avg: 160.81, max: 323)
#
# Run: 721, exploration: 0.01, score: 48
# Scores: (min: 47, avg: 159.65, max: 323)
#
# Run: 722, exploration: 0.01, score: 135
# Scores: (min: 47, avg: 159.36, max: 323)
#
# Run: 723, exploration: 0.01, score: 52
# Scores: (min: 47, avg: 157.94, max: 323)
#
# Run: 724, exploration: 0.01, score: 237
# Scores: (min: 47, avg: 158.63, max: 323)
#
# Run: 725, exploration: 0.01, score: 155
# Scores: (min: 47, avg: 158.31, max: 323)
#
# Run: 726, exploration: 0.01, score: 99
# Scores: (min: 47, avg: 157.35, max: 323)
#
# Run: 727, exploration: 0.01, score: 142
# Scores: (min: 47, avg: 156.97, max: 323)
#
# Run: 728, exploration: 0.01, score: 114
# Scores: (min: 48, avg: 157.64, max: 323)
#
# Run: 729, exploration: 0.01, score: 148
# Scores: (min: 48, avg: 157.29, max: 323)
#
# Run: 730, exploration: 0.01, score: 121
# Scores: (min: 48, avg: 157.16, max: 323)
#
# Run: 731, exploration: 0.01, score: 149
# Scores: (min: 48, avg: 156.98, max: 323)
#
# Run: 732, exploration: 0.01, score: 262
# Scores: (min: 48, avg: 157.52, max: 323)
#
# Run: 733, exploration: 0.01, score: 125
# Scores: (min: 48, avg: 157.07, max: 323)
#
# Run: 734, exploration: 0.01, score: 138
# Scores: (min: 48, avg: 156.97, max: 323)
#
# Run: 735, exploration: 0.01, score: 132
# Scores: (min: 48, avg: 156.9, max: 323)
#
# Run: 736, exploration: 0.01, score: 135
# Scores: (min: 48, avg: 156.39, max: 323)
#
# Run: 737, exploration: 0.01, score: 121
# Scores: (min: 48, avg: 155.66, max: 323)
#
# Run: 738, exploration: 0.01, score: 177
# Scores: (min: 48, avg: 155.31, max: 323)
#
# Run: 739, exploration: 0.01, score: 127
# Scores: (min: 48, avg: 155.21, max: 323)
#
# Run: 740, exploration: 0.01, score: 136
# Scores: (min: 48, avg: 155.19, max: 323)
#
# Run: 741, exploration: 0.01, score: 138
# Scores: (min: 48, avg: 154.73, max: 323)
#
# Run: 742, exploration: 0.01, score: 113
# Scores: (min: 48, avg: 154.34, max: 323)
#
# Run: 743, exploration: 0.01, score: 117
# Scores: (min: 48, avg: 154.59, max: 323)
#
# Run: 744, exploration: 0.01, score: 158
# Scores: (min: 48, avg: 154.41, max: 323)
#
# Run: 745, exploration: 0.01, score: 152
# Scores: (min: 48, avg: 154.68, max: 323)
#
# Run: 746, exploration: 0.01, score: 316
# Scores: (min: 48, avg: 155.07, max: 323)
#
# Run: 747, exploration: 0.01, score: 350
# Scores: (min: 48, avg: 157.01, max: 350)
#
# Run: 748, exploration: 0.01, score: 240
# Scores: (min: 48, avg: 158.28, max: 350)
#
# Run: 749, exploration: 0.01, score: 184
# Scores: (min: 48, avg: 158.88, max: 350)
#
# Run: 750, exploration: 0.01, score: 124
# Scores: (min: 48, avg: 158.75, max: 350)
#
# Run: 751, exploration: 0.01, score: 194
# Scores: (min: 48, avg: 159.53, max: 350)
#
# Run: 752, exploration: 0.01, score: 135
# Scores: (min: 48, avg: 158.67, max: 350)
#
# Run: 753, exploration: 0.01, score: 164
# Scores: (min: 48, avg: 158.7, max: 350)
#
# Run: 754, exploration: 0.01, score: 386
# Scores: (min: 48, avg: 160.47, max: 386)
#
# Run: 755, exploration: 0.01, score: 183
# Scores: (min: 48, avg: 159.82, max: 386)
#
# Run: 756, exploration: 0.01, score: 152
# Scores: (min: 48, avg: 159.43, max: 386)
#
# Run: 757, exploration: 0.01, score: 170
# Scores: (min: 48, avg: 159.96, max: 386)
#
# Run: 758, exploration: 0.01, score: 229
# Scores: (min: 48, avg: 160.94, max: 386)
#
# Run: 759, exploration: 0.01, score: 239
# Scores: (min: 48, avg: 162.09, max: 386)
#
# Run: 760, exploration: 0.01, score: 136
# Scores: (min: 48, avg: 162.49, max: 386)
#
# Run: 761, exploration: 0.01, score: 192
# Scores: (min: 48, avg: 162.02, max: 386)
#
# Run: 762, exploration: 0.01, score: 136
# Scores: (min: 48, avg: 162.02, max: 386)
#
# Run: 763, exploration: 0.01, score: 143
# Scores: (min: 48, avg: 161.39, max: 386)
#
# Run: 764, exploration: 0.01, score: 119
# Scores: (min: 48, avg: 161.1, max: 386)
#
# Run: 765, exploration: 0.01, score: 148
# Scores: (min: 48, avg: 160.91, max: 386)
#
# Run: 766, exploration: 0.01, score: 118
# Scores: (min: 48, avg: 160.93, max: 386)
#
# Run: 767, exploration: 0.01, score: 131
# Scores: (min: 48, avg: 161.19, max: 386)
#
# Run: 768, exploration: 0.01, score: 287
# Scores: (min: 48, avg: 162.59, max: 386)
#
# Run: 769, exploration: 0.01, score: 189
# Scores: (min: 48, avg: 161.25, max: 386)
#
# Run: 770, exploration: 0.01, score: 151
# Scores: (min: 48, avg: 161.58, max: 386)
#
# Run: 771, exploration: 0.01, score: 147
# Scores: (min: 48, avg: 162.04, max: 386)
#
# Run: 772, exploration: 0.01, score: 334
# Scores: (min: 48, avg: 164.49, max: 386)
#
# Run: 773, exploration: 0.01, score: 110
# Scores: (min: 48, avg: 164.02, max: 386)
#
# Run: 774, exploration: 0.01, score: 196
# Scores: (min: 48, avg: 164.08, max: 386)
#
# Run: 775, exploration: 0.01, score: 111
# Scores: (min: 48, avg: 163.99, max: 386)
#
# Run: 776, exploration: 0.01, score: 124
# Scores: (min: 48, avg: 164.05, max: 386)
#
# Run: 777, exploration: 0.01, score: 355
# Scores: (min: 48, avg: 165.57, max: 386)
#
# Run: 778, exploration: 0.01, score: 92
# Scores: (min: 48, avg: 164.55, max: 386)
#
# Run: 779, exploration: 0.01, score: 140
# Scores: (min: 48, avg: 164.29, max: 386)
#
# Run: 780, exploration: 0.01, score: 203
# Scores: (min: 48, avg: 164.73, max: 386)
#
# Run: 781, exploration: 0.01, score: 174
# Scores: (min: 48, avg: 164.67, max: 386)
#
# Run: 782, exploration: 0.01, score: 175
# Scores: (min: 48, avg: 164.99, max: 386)
#
# Run: 783, exploration: 0.01, score: 154
# Scores: (min: 48, avg: 165.3, max: 386)
#
# Run: 784, exploration: 0.01, score: 500
# Scores: (min: 48, avg: 168.78, max: 500)
#
# Run: 785, exploration: 0.01, score: 138
# Scores: (min: 48, avg: 168.13, max: 500)
#
# Run: 786, exploration: 0.01, score: 476
# Scores: (min: 48, avg: 170.82, max: 500)
#
# Run: 787, exploration: 0.01, score: 153
# Scores: (min: 48, avg: 171.08, max: 500)
#
# Run: 788, exploration: 0.01, score: 148
# Scores: (min: 48, avg: 170.67, max: 500)
#
# Run: 789, exploration: 0.01, score: 154
# Scores: (min: 48, avg: 170.34, max: 500)
#
# Run: 790, exploration: 0.01, score: 246
# Scores: (min: 48, avg: 171.35, max: 500)
#
# Run: 791, exploration: 0.01, score: 104
# Scores: (min: 48, avg: 170.91, max: 500)
#
# Run: 792, exploration: 0.01, score: 145
# Scores: (min: 48, avg: 171.16, max: 500)
#
# Run: 793, exploration: 0.01, score: 275
# Scores: (min: 48, avg: 172.41, max: 500)
# Run: 794, exploration: 0.01, score: 103
# Scores: (min: 48, avg: 171.46, max: 500)
#
# Run: 795, exploration: 0.01, score: 124
# Scores: (min: 48, avg: 170.41, max: 500)
#
# Run: 796, exploration: 0.01, score: 123
# Scores: (min: 48, avg: 170.28, max: 500)
#
# Run: 797, exploration: 0.01, score: 74
# Scores: (min: 48, avg: 169.96, max: 500)
#
# Run: 798, exploration: 0.01, score: 101
# Scores: (min: 48, avg: 169.52, max: 500)
#
# Run: 799, exploration: 0.01, score: 301
# Scores: (min: 48, avg: 170.6, max: 500)
#
# Run: 800, exploration: 0.01, score: 249
# Scores: (min: 48, avg: 171.59, max: 500)
#
# Run: 801, exploration: 0.01, score: 500
# Scores: (min: 48, avg: 175.55, max: 500)
#
# Run: 802, exploration: 0.01, score: 258
# Scores: (min: 48, avg: 176.22, max: 500)
#
# Run: 803, exploration: 0.01, score: 212
# Scores: (min: 48, avg: 176.86, max: 500)
#
# Run: 804, exploration: 0.01, score: 130
# Scores: (min: 48, avg: 176.95, max: 500)
#
# Run: 805, exploration: 0.01, score: 224
# Scores: (min: 48, avg: 176.03, max: 500)
#
# Run: 806, exploration: 0.01, score: 131
# Scores: (min: 48, avg: 175.25, max: 500)
#
# Run: 807, exploration: 0.01, score: 194
# Scores: (min: 48, avg: 175.87, max: 500)
#
# Run: 808, exploration: 0.01, score: 160
# Scores: (min: 48, avg: 175.55, max: 500)
#
# Run: 809, exploration: 0.01, score: 121
# Scores: (min: 48, avg: 175.44, max: 500)
#
# Run: 810, exploration: 0.01, score: 149
# Scores: (min: 48, avg: 175.24, max: 500)
#
# Run: 811, exploration: 0.01, score: 325
# Scores: (min: 48, avg: 177.17, max: 500)
#
# Run: 812, exploration: 0.01, score: 326
# Scores: (min: 48, avg: 179.21, max: 500)
#
# Run: 813, exploration: 0.01, score: 158
# Scores: (min: 48, avg: 178.93, max: 500)
#
# Run: 814, exploration: 0.01, score: 236
# Scores: (min: 48, avg: 180.04, max: 500)
#
# Run: 815, exploration: 0.01, score: 129
# Scores: (min: 48, avg: 179.36, max: 500)
#
# Run: 816, exploration: 0.01, score: 184
# Scores: (min: 48, avg: 179.49, max: 500)
#
# Run: 817, exploration: 0.01, score: 194
# Scores: (min: 48, avg: 179.86, max: 500)
#
# Run: 818, exploration: 0.01, score: 177
# Scores: (min: 48, avg: 180.61, max: 500)
#
# Run: 819, exploration: 0.01, score: 173
# Scores: (min: 48, avg: 180.9, max: 500)
#
# Run: 820, exploration: 0.01, score: 205
# Scores: (min: 48, avg: 181.62, max: 500)
#
# Run: 821, exploration: 0.01, score: 160
# Scores: (min: 52, avg: 182.74, max: 500)
#
# Run: 822, exploration: 0.01, score: 265
# Scores: (min: 52, avg: 184.04, max: 500)
#
# Run: 823, exploration: 0.01, score: 200
# Scores: (min: 74, avg: 185.52, max: 500)
#
# Run: 824, exploration: 0.01, score: 216
# Scores: (min: 74, avg: 185.31, max: 500)
#
# Run: 825, exploration: 0.01, score: 246
# Scores: (min: 74, avg: 186.22, max: 500)
#
# Run: 826, exploration: 0.01, score: 147
# Scores: (min: 74, avg: 186.7, max: 500)
#
# Run: 827, exploration: 0.01, score: 238
# Scores: (min: 74, avg: 187.66, max: 500)
#
# Run: 828, exploration: 0.01, score: 135
# Scores: (min: 74, avg: 187.87, max: 500)
#
# Run: 829, exploration: 0.01, score: 148
# Scores: (min: 74, avg: 187.87, max: 500)
#
# Run: 830, exploration: 0.01, score: 117
# Scores: (min: 74, avg: 187.83, max: 500)
#
# Run: 831, exploration: 0.01, score: 116
# Scores: (min: 74, avg: 187.5, max: 500)
#
# Run: 832, exploration: 0.01, score: 165
# Scores: (min: 74, avg: 186.53, max: 500)
#
# Run: 833, exploration: 0.01, score: 500
# Scores: (min: 74, avg: 190.28, max: 500)
#
# Run: 834, exploration: 0.01, score: 500
# Scores: (min: 74, avg: 193.9, max: 500)
#
# Run: 835, exploration: 0.01, score: 156
# Scores: (min: 74, avg: 194.14, max: 500)
#
# Run: 836, exploration: 0.01, score: 404
# Scores: (min: 74, avg: 196.83, max: 500)
#
# Solved in 736 runs, 836 total runs.
# ----------------------------------------------------------
# NameError                Traceback (most recent call last)
# <ipython-input-2-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 1.0 # Changed from 0.95 to 1.0 
LEARNING_RATE = 0.015 # Changed from 0.001 to 0.015  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.05 # Changed form 0.01 to 0.05
EXPLORATION_DECAY = 0.975 # Changed from 0.995 to 0.975  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 12
# Scores: (min: 12, avg: 12, max: 12)
#
# Run: 2, exploration: 0.70155967750146, score: 22
# Scores: (min: 12, avg: 17, max: 22)
#
# Run: 3, exploration: 0.558606726608075, score: 10
# Scores: (min: 10, avg: 14.666666666666666, max: 22)
#
# Run: 4, exploration: 0.3120414750117885, score: 24
# Scores: (min: 10, avg: 17, max: 24)
#
# Run: 5, exploration: 0.19783148213754234, score: 19
# Scores: (min: 10, avg: 17.4, max: 24)
#
# Run: 6, exploration: 0.10774724674045444, score: 25
# Scores: (min: 10, avg: 18.666666666666668, max: 25)
#
# Run: 7, exploration: 0.05439147112547512, score: 28
# Scores: (min: 10, avg: 20, max: 28)
#
# Run: 8, exploration: 0.05, score: 16
# Scores: (min: 10, avg: 19.5, max: 28)
#
# Run: 9, exploration: 0.05, score: 26
# Scores: (min: 10, avg: 20.22222222222222, max: 28)
#
# Run: 10, exploration: 0.05, score: 10
# Scores: (min: 10, avg: 19.2, max: 28)
#
# Run: 11, exploration: 0.05, score: 14
# Scores: (min: 10, avg: 18.727272727272727, max: 28)
#
# Run: 12, exploration: 0.05, score: 16
# Scores: (min: 10, avg: 18.5, max: 28)
#
# Run: 13, exploration: 0.05, score: 24
# Scores: (min: 10, avg: 18.923076923076923, max: 28)
#
# Run: 14, exploration: 0.05, score: 25
# Scores: (min: 10, avg: 19.357142857142858, max: 28)
#
# Run: 15, exploration: 0.05, score: 26
# Scores: (min: 10, avg: 19.8, max: 28)
#
# Run: 16, exploration: 0.05, score: 11
# Scores: (min: 10, avg: 19.25, max: 28)
#
# Run: 17, exploration: 0.05, score: 13
# Scores: (min: 10, avg: 18.88235294117647, max: 28)
#
# Run: 18, exploration: 0.05, score: 11
# Scores: (min: 10, avg: 18.444444444444443, max: 28)
#
# Run: 19, exploration: 0.05, score: 10
# Scores: (min: 10, avg: 18, max: 28)
#
# Run: 20, exploration: 0.05, score: 9
# Scores: (min: 9, avg: 17.55, max: 28)
#
# Run: 21, exploration: 0.05, score: 9
# Scores: (min: 9, avg: 17.142857142857142, max: 28)
#
# Run: 22, exploration: 0.05, score: 11
# Scores: (min: 9, avg: 16.863636363636363, max: 28)
#
# Run: 23, exploration: 0.05, score: 9
# Scores: (min: 9, avg: 16.52173913043478, max: 28)
#
# Run: 24, exploration: 0.05, score: 12
# Scores: (min: 9, avg: 16.333333333333332, max: 28)
#
# Run: 25, exploration: 0.05, score: 9
# Scores: (min: 9, avg: 16.04, max: 28)
#
# Run: 26, exploration: 0.05, score: 9
# Scores: (min: 9, avg: 15.76923076923077, max: 28)
#
# Run: 27, exploration: 0.05, score: 10
# Scores: (min: 9, avg: 15.555555555555555, max: 28)
#
# Run: 28, exploration: 0.05, score: 9
# Scores: (min: 9, avg: 15.321428571428571, max: 28)
#
# Run: 29, exploration: 0.05, score: 10
# Scores: (min: 9, avg: 15.137931034482758, max: 28)
#
# Run: 30, exploration: 0.05, score: 9
# Scores: (min: 9, avg: 14.933333333333334, max: 28)
#
# Run: 31, exploration: 0.05, score: 9
# Scores: (min: 9, avg: 14.741935483870968, max: 28)
#
# Run: 32, exploration: 0.05, score: 18
# Scores: (min: 9, avg: 14.84375, max: 28)
#
# Run: 33, exploration: 0.05, score: 10
# Scores: (min: 9, avg: 14.696969696969697, max: 28)
#
# Run: 34, exploration: 0.05, score: 10
# Scores: (min: 9, avg: 14.558823529411764, max: 28)
#
# Run: 35, exploration: 0.05, score: 9
# Scores: (min: 9, avg: 14.4, max: 28)
#
# Run: 36, exploration: 0.05, score: 11
# Scores: (min: 9, avg: 14.305555555555555, max: 28)
#
# Run: 37, exploration: 0.05, score: 47
# Scores: (min: 9, avg: 15.18918918918919, max: 47)
#
# Run: 38, exploration: 0.05, score: 29
# Scores: (min: 9, avg: 15.552631578947368, max: 47)
#
# Run: 39, exploration: 0.05, score: 11
# Scores: (min: 9, avg: 15.435897435897436, max: 47)
#
# Run: 40, exploration: 0.05, score: 8
# Scores: (min: 8, avg: 15.25, max: 47)
#
# Run: 41, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 15.121951219512194, max: 47)
#
# Run: 42, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 15, max: 47)
#
# Run: 43, exploration: 0.05, score: 11
# Scores: (min: 8, avg: 14.906976744186046, max: 47)
#
# Run: 44, exploration: 0.05, score: 11
# Scores: (min: 8, avg: 14.818181818181818, max: 47)
#
# Run: 45, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 14.71111111111111, max: 47)
#
# Run: 46, exploration: 0.05, score: 13
# Scores: (min: 8, avg: 14.673913043478262, max: 47)
#
# Run: 47, exploration: 0.05, score: 22
# Scores: (min: 8, avg: 14.829787234042554, max: 47)
#
# Run: 48, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 14.708333333333334, max: 47)
#
# Run: 49, exploration: 0.05, score: 12
# Scores: (min: 8, avg: 14.653061224489797, max: 47)
#
# Run: 50, exploration: 0.05, score: 12
# Scores: (min: 8, avg: 14.6, max: 47)
#
# Run: 51, exploration: 0.05, score: 13
# Scores: (min: 8, avg: 14.568627450980392, max: 47)
#
# Run: 52, exploration: 0.05, score: 8
# Scores: (min: 8, avg: 14.442307692307692, max: 47)
#
# Run: 53, exploration: 0.05, score: 25
# Scores: (min: 8, avg: 14.641509433962264, max: 47)
#
# Run: 54, exploration: 0.05, score: 24
# Scores: (min: 8, avg: 14.814814814814815, max: 47)
#
# Run: 55, exploration: 0.05, score: 43
# Scores: (min: 8, avg: 15.327272727272728, max: 47)
#
# Run: 56, exploration: 0.05, score: 24
# Scores: (min: 8, avg: 15.482142857142858, max: 47)
#
# Run: 57, exploration: 0.05, score: 59
# Scores: (min: 8, avg: 16.24561403508772, max: 59)
#
# Run: 58, exploration: 0.05, score: 34
# Scores: (min: 8, avg: 16.551724137931036, max: 59)
#
# Run: 59, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 16.440677966101696, max: 59)
#
# Run: 60, exploration: 0.05, score: 31
# Scores: (min: 8, avg: 16.683333333333334, max: 59)
#
# Run: 61, exploration: 0.05, score: 11
# Scores: (min: 8, avg: 16.59016393442623, max: 59)
#
# Run: 62, exploration: 0.05, score: 16
# Scores: (min: 8, avg: 16.580645161290324, max: 59)
#
# Run: 63, exploration: 0.05, score: 41
# Scores: (min: 8, avg: 16.96825396825397, max: 59)
#
# Run: 64, exploration: 0.05, score: 29
# Scores: (min: 8, avg: 17.15625, max: 59)
#
# Run: 65, exploration: 0.05, score: 61
# Scores: (min: 8, avg: 17.83076923076923, max: 61)
#
# Run: 66, exploration: 0.05, score: 41
# Scores: (min: 8, avg: 18.181818181818183, max: 61)
#
# Run: 67, exploration: 0.05, score: 75
# Scores: (min: 8, avg: 19.029850746268657, max: 75)
#
# Run: 68, exploration: 0.05, score: 19
# Scores: (min: 8, avg: 19.029411764705884, max: 75)
#
# Run: 69, exploration: 0.05, score: 34
# Scores: (min: 8, avg: 19.246376811594203, max: 75)
#
# Run: 70, exploration: 0.05, score: 29
# Scores: (min: 8, avg: 19.385714285714286, max: 75)
#
# Run: 71, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 19.253521126760564, max: 75)
#
# Run: 72, exploration: 0.05, score: 11
# Scores: (min: 8, avg: 19.13888888888889, max: 75)
#
# Run: 73, exploration: 0.05, score: 8
# Scores: (min: 8, avg: 18.986301369863014, max: 75)
#
# Run: 74, exploration: 0.05, score: 11
# Scores: (min: 8, avg: 18.87837837837838, max: 75)
#
# Run: 75, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 18.76, max: 75)
#
# Run: 76, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 18.644736842105264, max: 75)
#
# Run: 77, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 18.532467532467532, max: 75)
#
# Run: 78, exploration: 0.05, score: 11
# Scores: (min: 8, avg: 18.435897435897434, max: 75)
#
# Run: 79, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 18.31645569620253, max: 75)
#
# Run: 80, exploration: 0.05, score: 8
# Scores: (min: 8, avg: 18.1875, max: 75)
#
# Run: 81, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 18.074074074074073, max: 75)
#
# Run: 82, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 17.975609756097562, max: 75)
#
# Run: 83, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 17.867469879518072, max: 75)
#
# Run: 84, exploration: 0.05, score: 8
# Scores: (min: 8, avg: 17.75, max: 75)
#
# Run: 85, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 17.658823529411766, max: 75)
#
# Run: 86, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 17.569767441860463, max: 75)
#
# Run: 87, exploration: 0.05, score: 15
# Scores: (min: 8, avg: 17.54022988505747, max: 75)
#
# Run: 88, exploration: 0.05, score: 29
# Scores: (min: 8, avg: 17.670454545454547, max: 75)
#
# Run: 89, exploration: 0.05, score: 76
# Scores: (min: 8, avg: 18.325842696629213, max: 76)
#
# Run: 90, exploration: 0.05, score: 50
# Scores: (min: 8, avg: 18.677777777777777, max: 76)
#
# Run: 91, exploration: 0.05, score: 37
# Scores: (min: 8, avg: 18.87912087912088, max: 76)
#
# Run: 92, exploration: 0.05, score: 22
# Scores: (min: 8, avg: 18.91304347826087, max: 76)
#
# Run: 93, exploration: 0.05, score: 52
# Scores: (min: 8, avg: 19.268817204301076, max: 76)
#
# Run: 94, exploration: 0.05, score: 14
# Scores: (min: 8, avg: 19.21276595744681, max: 76)
# Run: 95, exploration: 0.05, score: 31
# Scores: (min: 8, avg: 19.33684210526316, max: 76)
#
# Run: 96, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 19.229166666666668, max: 76)
#
# Run: 97, exploration: 0.05, score: 32
# Scores: (min: 8, avg: 19.36082474226804, max: 76)
#
# Run: 98, exploration: 0.05, score: 17
# Scores: (min: 8, avg: 19.336734693877553, max: 76)
#
# Run: 99, exploration: 0.05, score: 34
# Scores: (min: 8, avg: 19.484848484848484, max: 76)
#
# Run: 100, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 19.38, max: 76)
#
# Run: 101, exploration: 0.05, score: 29
# Scores: (min: 8, avg: 19.55, max: 76)
#
# Run: 102, exploration: 0.05, score: 20
# Scores: (min: 8, avg: 19.53, max: 76)
#
# Run: 103, exploration: 0.05, score: 23
# Scores: (min: 8, avg: 19.66, max: 76)
#
# Run: 104, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 19.51, max: 76)
#
# Run: 105, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 19.41, max: 76)
#
# Run: 106, exploration: 0.05, score: 12
# Scores: (min: 8, avg: 19.28, max: 76)
#
# Run: 107, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 19.1, max: 76)
#
# Run: 108, exploration: 0.05, score: 8
# Scores: (min: 8, avg: 19.02, max: 76)
#
# Run: 109, exploration: 0.05, score: 14
# Scores: (min: 8, avg: 18.9, max: 76)
#
# Run: 110, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 18.9, max: 76)
#
# Run: 111, exploration: 0.05, score: 43
# Scores: (min: 8, avg: 19.19, max: 76)
#
# Run: 112, exploration: 0.05, score: 56
# Scores: (min: 8, avg: 19.59, max: 76)
#
# Run: 113, exploration: 0.05, score: 77
# Scores: (min: 8, avg: 20.12, max: 77)
#
# Run: 114, exploration: 0.05, score: 69
# Scores: (min: 8, avg: 20.56, max: 77)
#
# Run: 115, exploration: 0.05, score: 60
# Scores: (min: 8, avg: 20.9, max: 77)
#
# Run: 116, exploration: 0.05, score: 58
# Scores: (min: 8, avg: 21.37, max: 77)
#
# Run: 117, exploration: 0.05, score: 43
# Scores: (min: 8, avg: 21.67, max: 77)
#
# Run: 118, exploration: 0.05, score: 19
# Scores: (min: 8, avg: 21.75, max: 77)
#
# Run: 119, exploration: 0.05, score: 29
# Scores: (min: 8, avg: 21.94, max: 77)
#
# Run: 120, exploration: 0.05, score: 27
# Scores: (min: 8, avg: 22.12, max: 77)
#
# Run: 121, exploration: 0.05, score: 31
# Scores: (min: 8, avg: 22.34, max: 77)
#
# Run: 122, exploration: 0.05, score: 17
# Scores: (min: 8, avg: 22.4, max: 77)
#
# Run: 123, exploration: 0.05, score: 22
# Scores: (min: 8, avg: 22.53, max: 77)
#
# Run: 124, exploration: 0.05, score: 23
# Scores: (min: 8, avg: 22.64, max: 77)
#
# Run: 125, exploration: 0.05, score: 32
# Scores: (min: 8, avg: 22.87, max: 77)
#
# Run: 126, exploration: 0.05, score: 46
# Scores: (min: 8, avg: 23.24, max: 77)
#
# Run: 127, exploration: 0.05, score: 41
# Scores: (min: 8, avg: 23.55, max: 77)
#
# Run: 128, exploration: 0.05, score: 11
# Scores: (min: 8, avg: 23.57, max: 77)
#
# Run: 129, exploration: 0.05, score: 44
# Scores: (min: 8, avg: 23.91, max: 77)
#
# Run: 130, exploration: 0.05, score: 78
# Scores: (min: 8, avg: 24.6, max: 78)
#
# Run: 131, exploration: 0.05, score: 149
# Scores: (min: 8, avg: 26, max: 149)
#
# Run: 132, exploration: 0.05, score: 205
# Scores: (min: 8, avg: 27.87, max: 205)
#
# Run: 133, exploration: 0.05, score: 106
# Scores: (min: 8, avg: 28.83, max: 205)
#
# Run: 134, exploration: 0.05, score: 109
# Scores: (min: 8, avg: 29.82, max: 205)
#
# Run: 135, exploration: 0.05, score: 333
# Scores: (min: 8, avg: 33.06, max: 333)
#
# Run: 136, exploration: 0.05, score: 275
# Scores: (min: 8, avg: 35.7, max: 333)
#
# Run: 137, exploration: 0.05, score: 251
# Scores: (min: 8, avg: 37.74, max: 333)
#
# Run: 138, exploration: 0.05, score: 185
# Scores: (min: 8, avg: 39.3, max: 333)
#
# Run: 139, exploration: 0.05, score: 185
# Scores: (min: 8, avg: 41.04, max: 333)
#
# Run: 140, exploration: 0.05, score: 171
# Scores: (min: 8, avg: 42.67, max: 333)
#
# Run: 141, exploration: 0.05, score: 164
# Scores: (min: 8, avg: 44.21, max: 333)
#
# Run: 142, exploration: 0.05, score: 231
# Scores: (min: 8, avg: 46.42, max: 333)
#
# Run: 143, exploration: 0.05, score: 182
# Scores: (min: 8, avg: 48.13, max: 333)
#
# Run: 144, exploration: 0.05, score: 500
# Scores: (min: 8, avg: 53.02, max: 500)
#
# Run: 145, exploration: 0.05, score: 500
# Scores: (min: 8, avg: 57.92, max: 500)
#
# Run: 146, exploration: 0.05, score: 309
# Scores: (min: 8, avg: 60.88, max: 500)
#
# Run: 147, exploration: 0.05, score: 201
# Scores: (min: 8, avg: 62.67, max: 500)
#
# Run: 148, exploration: 0.05, score: 180
# Scores: (min: 8, avg: 64.38, max: 500)
#
# Run: 149, exploration: 0.05, score: 225
# Scores: (min: 8, avg: 66.51, max: 500)
#
# Run: 150, exploration: 0.05, score: 149
# Scores: (min: 8, avg: 67.88, max: 500)
#
# Run: 151, exploration: 0.05, score: 114
# Scores: (min: 8, avg: 68.89, max: 500)
#
# Run: 152, exploration: 0.05, score: 143
# Scores: (min: 8, avg: 70.24, max: 500)
#
# Run: 153, exploration: 0.05, score: 88
# Scores: (min: 8, avg: 70.87, max: 500)
#
# Run: 154, exploration: 0.05, score: 123
# Scores: (min: 8, avg: 71.86, max: 500)
#
# Run: 155, exploration: 0.05, score: 150
# Scores: (min: 8, avg: 72.93, max: 500)
#
# Run: 156, exploration: 0.05, score: 64
# Scores: (min: 8, avg: 73.33, max: 500)
#
# Run: 157, exploration: 0.05, score: 64
# Scores: (min: 8, avg: 73.38, max: 500)
#
# Run: 158, exploration: 0.05, score: 80
# Scores: (min: 8, avg: 73.84, max: 500)
#
# Run: 159, exploration: 0.05, score: 140
# Scores: (min: 8, avg: 75.14, max: 500)
#
# Run: 160, exploration: 0.05, score: 80
# Scores: (min: 8, avg: 75.63, max: 500)
#
# Run: 161, exploration: 0.05, score: 82
# Scores: (min: 8, avg: 76.34, max: 500)
#
# Run: 162, exploration: 0.05, score: 76
# Scores: (min: 8, avg: 76.94, max: 500)
#
# Run: 163, exploration: 0.05, score: 116
# Scores: (min: 8, avg: 77.69, max: 500)
#
# Run: 164, exploration: 0.05, score: 164
# Scores: (min: 8, avg: 79.04, max: 500)
#
# Run: 165, exploration: 0.05, score: 193
# Scores: (min: 8, avg: 80.36, max: 500)
#
# Run: 166, exploration: 0.05, score: 126
# Scores: (min: 8, avg: 81.21, max: 500)
#
# Run: 167, exploration: 0.05, score: 123
# Scores: (min: 8, avg: 81.69, max: 500)
#
# Run: 168, exploration: 0.05, score: 75
# Scores: (min: 8, avg: 82.25, max: 500)
#
# Run: 169, exploration: 0.05, score: 127
# Scores: (min: 8, avg: 83.18, max: 500)
#
# Run: 170, exploration: 0.05, score: 146
# Scores: (min: 8, avg: 84.35, max: 500)
#
# Run: 171, exploration: 0.05, score: 172
# Scores: (min: 8, avg: 85.97, max: 500)
#
# Run: 172, exploration: 0.05, score: 70
# Scores: (min: 8, avg: 86.56, max: 500)
#
# Run: 173, exploration: 0.05, score: 206
# Scores: (min: 8, avg: 88.54, max: 500)
#
# Run: 174, exploration: 0.05, score: 156
# Scores: (min: 8, avg: 89.99, max: 500)
#
# Run: 175, exploration: 0.05, score: 124
# Scores: (min: 8, avg: 91.13, max: 500)
#
# Run: 176, exploration: 0.05, score: 129
# Scores: (min: 8, avg: 92.32, max: 500)
#
# Run: 177, exploration: 0.05, score: 97
# Scores: (min: 8, avg: 93.19, max: 500)
#
# Run: 178, exploration: 0.05, score: 171
# Scores: (min: 8, avg: 94.79, max: 500)
#
# Run: 179, exploration: 0.05, score: 133
# Scores: (min: 8, avg: 96.03, max: 500)
#
# Run: 180, exploration: 0.05, score: 159
# Scores: (min: 8, avg: 97.54, max: 500)
#
# Run: 181, exploration: 0.05, score: 178
# Scores: (min: 8, avg: 99.23, max: 500)
#
# Run: 182, exploration: 0.05, score: 187
# Scores: (min: 8, avg: 101, max: 500)
#
# Run: 183, exploration: 0.05, score: 306
# Scores: (min: 8, avg: 103.97, max: 500)
#
# Run: 184, exploration: 0.05, score: 118
# Scores: (min: 8, avg: 105.07, max: 500)
#
# Run: 185, exploration: 0.05, score: 108
# Scores: (min: 8, avg: 106.05, max: 500)
#
# Run: 186, exploration: 0.05, score: 274
# Scores: (min: 8, avg: 108.69, max: 500)
#
# Run: 187, exploration: 0.05, score: 210
# Scores: (min: 8, avg: 110.64, max: 500)
#
# Run: 188, exploration: 0.05, score: 125
# Scores: (min: 8, avg: 111.6, max: 500)
#
# Run: 189, exploration: 0.05, score: 359
# Scores: (min: 8, avg: 114.43, max: 500)
#
# Run: 190, exploration: 0.05, score: 208
# Scores: (min: 8, avg: 116.01, max: 500)
#
# Run: 191, exploration: 0.05, score: 86
# Scores: (min: 8, avg: 116.5, max: 500)
#
# Run: 192, exploration: 0.05, score: 99
# Scores: (min: 8, avg: 117.27, max: 500)
#
# Run: 193, exploration: 0.05, score: 105
# Scores: (min: 8, avg: 117.8, max: 500)
#
# Run: 194, exploration: 0.05, score: 137
# Scores: (min: 8, avg: 119.03, max: 500)
#
# Run: 195, exploration: 0.05, score: 138
# Scores: (min: 8, avg: 120.1, max: 500)
#
# Run: 196, exploration: 0.05, score: 187
# Scores: (min: 8, avg: 121.88, max: 500)
#
# Run: 197, exploration: 0.05, score: 159
# Scores: (min: 8, avg: 123.15, max: 500)
# Run: 198, exploration: 0.05, score: 142
# Scores: (min: 8, avg: 124.4, max: 500)
#
# Run: 199, exploration: 0.05, score: 163
# Scores: (min: 8, avg: 125.69, max: 500)
#
# Run: 200, exploration: 0.05, score: 182
# Scores: (min: 8, avg: 127.42, max: 500)
#
# Run: 201, exploration: 0.05, score: 156
# Scores: (min: 8, avg: 128.69, max: 500)
#
# Run: 202, exploration: 0.05, score: 129
# Scores: (min: 8, avg: 129.78, max: 500)
#
# Run: 203, exploration: 0.05, score: 244
# Scores: (min: 8, avg: 131.99, max: 500)
#
# Run: 204, exploration: 0.05, score: 125
# Scores: (min: 8, avg: 133.15, max: 500)
#
# Run: 205, exploration: 0.05, score: 136
# Scores: (min: 8, avg: 134.42, max: 500)
#
# Run: 206, exploration: 0.05, score: 291
# Scores: (min: 8, avg: 137.21, max: 500)
#
# Run: 207, exploration: 0.05, score: 187
# Scores: (min: 8, avg: 138.98, max: 500)
#
# Run: 208, exploration: 0.05, score: 126
# Scores: (min: 10, avg: 140.16, max: 500)
#
# Run: 209, exploration: 0.05, score: 177
# Scores: (min: 10, avg: 141.79, max: 500)
#
# Run: 210, exploration: 0.05, score: 384
# Scores: (min: 11, avg: 145.53, max: 500)
#
# Run: 211, exploration: 0.05, score: 122
# Scores: (min: 11, avg: 146.32, max: 500)
#
# Run: 212, exploration: 0.05, score: 199
# Scores: (min: 11, avg: 147.75, max: 500)
#
# Run: 213, exploration: 0.05, score: 500
# Scores: (min: 11, avg: 151.98, max: 500)
#
# Run: 214, exploration: 0.05, score: 427
# Scores: (min: 11, avg: 155.56, max: 500)
#
# Run: 215, exploration: 0.05, score: 356
# Scores: (min: 11, avg: 158.52, max: 500)
#
# Run: 216, exploration: 0.05, score: 260
# Scores: (min: 11, avg: 160.54, max: 500)
#
# Run: 217, exploration: 0.05, score: 250
# Scores: (min: 11, avg: 162.61, max: 500)
#
# Run: 218, exploration: 0.05, score: 204
# Scores: (min: 11, avg: 164.46, max: 500)
#
# Run: 219, exploration: 0.05, score: 206
# Scores: (min: 11, avg: 166.23, max: 500)
#
# Run: 220, exploration: 0.05, score: 158
# Scores: (min: 11, avg: 167.54, max: 500)
#
# Run: 221, exploration: 0.05, score: 215
# Scores: (min: 11, avg: 169.38, max: 500)
#
# Run: 222, exploration: 0.05, score: 232
# Scores: (min: 11, avg: 171.53, max: 500)
#
# Run: 223, exploration: 0.05, score: 500
# Scores: (min: 11, avg: 176.31, max: 500)
#
# Run: 224, exploration: 0.05, score: 127
# Scores: (min: 11, avg: 177.35, max: 500)
#
# Run: 225, exploration: 0.05, score: 272
# Scores: (min: 11, avg: 179.75, max: 500)
#
# Run: 226, exploration: 0.05, score: 182
# Scores: (min: 11, avg: 181.11, max: 500)
#
# Run: 227, exploration: 0.05, score: 408
# Scores: (min: 11, avg: 184.78, max: 500)
#
# Run: 228, exploration: 0.05, score: 175
# Scores: (min: 44, avg: 186.42, max: 500)
#
# Run: 229, exploration: 0.05, score: 230
# Scores: (min: 64, avg: 188.28, max: 500)
#
# Run: 230, exploration: 0.05, score: 186
# Scores: (min: 64, avg: 189.36, max: 500)
#
# Run: 231, exploration: 0.05, score: 220
# Scores: (min: 64, avg: 190.07, max: 500)
#
# Run: 232, exploration: 0.05, score: 181
# Scores: (min: 64, avg: 189.83, max: 500)
#
# Run: 233, exploration: 0.05, score: 320
# Scores: (min: 64, avg: 191.97, max: 500)
#
# Run: 234, exploration: 0.05, score: 230
# Scores: (min: 64, avg: 193.18, max: 500)
#
# Run: 235, exploration: 0.05, score: 263
# Scores: (min: 64, avg: 192.48, max: 500)
#
# Run: 236, exploration: 0.05, score: 467
# Scores: (min: 64, avg: 194.4, max: 500)
#
# Run: 237, exploration: 0.05, score: 358
# Scores: (min: 64, avg: 195.47, max: 500)
#
# Solved in 137 runs, 237 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-e0255e85c49d> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 1.0 # Changed from 0.95 to 1.0 
LEARNING_RATE = 0.025 # Changed from 0.015 to 0.025  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.075 # Changed form 0.05 to 0.075
EXPLORATION_DECAY = 0.999 # Changed from 0.975 to 0.999  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 16
# Scores: (min: 16, avg: 16, max: 16)
#
# Run: 2, exploration: 0.9821521870514506, score: 22
# Scores: (min: 16, avg: 19, max: 22)
#
# Run: 3, exploration: 0.9694605362958227, score: 14
# Scores: (min: 14, avg: 17.333333333333332, max: 22)
#
# Run: 4, exploration: 0.9531108968798944, score: 18
# Scores: (min: 14, avg: 17.5, max: 22)
#
# Run: 5, exploration: 0.925854183751895, score: 30
# Scores: (min: 14, avg: 20, max: 30)
#
# Run: 6, exploration: 0.9093297114626595, score: 19
# Scores: (min: 14, avg: 19.833333333333332, max: 30)
#
# Run: 7, exploration: 0.8913148576343527, score: 21
# Scores: (min: 14, avg: 20, max: 30)
#
# Run: 8, exploration: 0.8701675093639105, score: 25
# Scores: (min: 14, avg: 20.625, max: 30)
#
# Run: 9, exploration: 0.8351949903256736, score: 42
# Scores: (min: 14, avg: 23, max: 42)
#
# Run: 10, exploration: 0.8227543820685892, score: 16
# Scores: (min: 14, avg: 22.3, max: 42)
#
# Run: 11, exploration: 0.8040377382995522, score: 24
# Scores: (min: 14, avg: 22.454545454545453, max: 42)
#
# Run: 12, exploration: 0.7833919908382508, score: 27
# Scores: (min: 14, avg: 22.833333333333332, max: 42)
#
# Run: 13, exploration: 0.7655707927460921, score: 24
# Scores: (min: 14, avg: 22.923076923076923, max: 42)
#
# Run: 14, exploration: 0.7325998717165821, score: 45
# Scores: (min: 14, avg: 24.5, max: 45)
#
# Run: 15, exploration: 0.7195245662400531, score: 19
# Scores: (min: 14, avg: 24.133333333333333, max: 45)
#
# Run: 16, exploration: 0.6989478686545415, score: 30
# Scores: (min: 14, avg: 24.5, max: 45)
#
# Run: 17, exploration: 0.6906064713669134, score: 13
# Scores: (min: 13, avg: 23.823529411764707, max: 45)
#
# Run: 18, exploration: 0.6816822575233553, score: 14
# Scores: (min: 13, avg: 23.27777777777778, max: 45)
#
# Run: 19, exploration: 0.6755716005914124, score: 10
# Scores: (min: 10, avg: 22.57894736842105, max: 45)
#
# Run: 20, exploration: 0.6641783033340387, score: 18
# Scores: (min: 10, avg: 22.35, max: 45)
#
# Run: 21, exploration: 0.6562518536710664, score: 13
# Scores: (min: 10, avg: 21.904761904761905, max: 45)
#
# Run: 22, exploration: 0.6510201771893979, score: 9
# Scores: (min: 9, avg: 21.318181818181817, max: 45)
#
# Run: 23, exploration: 0.6451843777173236, score: 10
# Scores: (min: 9, avg: 20.82608695652174, max: 45)
#
# Run: 24, exploration: 0.6374846057319378, score: 13
# Scores: (min: 9, avg: 20.5, max: 45)
#
# Run: 25, exploration: 0.6248553120386914, score: 21
# Scores: (min: 9, avg: 20.52, max: 45)
#
# Run: 26, exploration: 0.6192540566123834, score: 10
# Scores: (min: 9, avg: 20.115384615384617, max: 45)
#
# Run: 27, exploration: 0.6124762189899097, score: 12
# Scores: (min: 9, avg: 19.814814814814813, max: 45)
#
# Run: 28, exploration: 0.6003423698268052, score: 21
# Scores: (min: 9, avg: 19.857142857142858, max: 45)
#
# Run: 29, exploration: 0.5937715237303958, score: 12
# Scores: (min: 9, avg: 19.586206896551722, max: 45)
#
# Run: 30, exploration: 0.5860986387058792, score: 14
# Scores: (min: 9, avg: 19.4, max: 45)
#
# Run: 31, exploration: 0.577368433605742, score: 16
# Scores: (min: 9, avg: 19.29032258064516, max: 45)
#
# Run: 32, exploration: 0.5704779919833761, score: 13
# Scores: (min: 9, avg: 19.09375, max: 45)
#
# Run: 33, exploration: 0.5647988152354793, score: 11
# Scores: (min: 9, avg: 18.848484848484848, max: 45)
#
# Run: 34, exploration: 0.5563858806683429, score: 16
# Scores: (min: 9, avg: 18.764705882352942, max: 45)
#
# Run: 35, exploration: 0.5497458494385241, score: 13
# Scores: (min: 9, avg: 18.6, max: 45)
#
# Run: 36, exploration: 0.5426418767371284, score: 14
# Scores: (min: 9, avg: 18.47222222222222, max: 45)
#
# Run: 37, exploration: 0.5367025720391522, score: 12
# Scores: (min: 9, avg: 18.2972972972973, max: 45)
#
# Run: 38, exploration: 0.5302974457351142, score: 13
# Scores: (min: 9, avg: 18.157894736842106, max: 45)
#
# Run: 39, exploration: 0.5255438149533099, score: 10
# Scores: (min: 9, avg: 17.94871794871795, max: 45)
#
# Run: 40, exploration: 0.5177156014229363, score: 16
# Scores: (min: 9, avg: 17.9, max: 45)
#
# Run: 41, exploration: 0.5105145071914643, score: 15
# Scores: (min: 9, avg: 17.829268292682926, max: 45)
#
# Run: 42, exploration: 0.5029101620180685, score: 16
# Scores: (min: 9, avg: 17.785714285714285, max: 45)
#
# Run: 43, exploration: 0.4895066468838467, score: 28
# Scores: (min: 9, avg: 18.023255813953487, max: 45)
#
# Run: 44, exploration: 0.4793291555710539, score: 22
# Scores: (min: 9, avg: 18.113636363636363, max: 45)
#
# Run: 45, exploration: 0.4731351274767304, score: 14
# Scores: (min: 9, avg: 18.022222222222222, max: 45)
#
# Run: 46, exploration: 0.4684250106057235, score: 11
# Scores: (min: 9, avg: 17.869565217391305, max: 45)
#
# Run: 47, exploration: 0.46329802172888124, score: 12
# Scores: (min: 9, avg: 17.74468085106383, max: 45)
#
# Run: 48, exploration: 0.45776892144096987, score: 13
# Scores: (min: 9, avg: 17.645833333333332, max: 45)
#
# Run: 49, exploration: 0.4536654424342049, score: 10
# Scores: (min: 9, avg: 17.489795918367346, max: 45)
#
# Run: 50, exploration: 0.4491491486100748, score: 11
# Scores: (min: 9, avg: 17.36, max: 45)
#
# Run: 51, exploration: 0.44334511517564335, score: 14
# Scores: (min: 9, avg: 17.294117647058822, max: 45)
#
# Run: 52, exploration: 0.4376160831170627, score: 14
# Scores: (min: 9, avg: 17.23076923076923, max: 45)
#
# Run: 53, exploration: 0.42595277973599555, score: 28
# Scores: (min: 9, avg: 17.433962264150942, max: 45)
#
# Run: 54, exploration: 0.42255706035237733, score: 9
# Scores: (min: 9, avg: 17.27777777777778, max: 45)
#
# Run: 55, exploration: 0.41835045419835276, score: 11
# Scores: (min: 9, avg: 17.163636363636364, max: 45)
#
# Run: 56, exploration: 0.41377153958718943, score: 12
# Scores: (min: 9, avg: 17.071428571428573, max: 45)
#
# Run: 57, exploration: 0.40924274195045723, score: 12
# Scores: (min: 9, avg: 16.982456140350877, max: 45)
#
# Run: 58, exploration: 0.40516868143104934, score: 11
# Scores: (min: 9, avg: 16.879310344827587, max: 45)
#
# Run: 59, exploration: 0.4015367153875324, score: 10
# Scores: (min: 9, avg: 16.76271186440678, max: 45)
#
# Run: 60, exploration: 0.39753936928566525, score: 11
# Scores: (min: 9, avg: 16.666666666666668, max: 45)
#
# Run: 61, exploration: 0.39279504719041636, score: 13
# Scores: (min: 9, avg: 16.60655737704918, max: 45)
#
# Run: 62, exploration: 0.3888847254426181, score: 11
# Scores: (min: 9, avg: 16.516129032258064, max: 45)
#
# Run: 63, exploration: 0.3850133314162377, score: 11
# Scores: (min: 9, avg: 16.428571428571427, max: 45)
#
# Run: 64, exploration: 0.38118047758114515, score: 11
# Scores: (min: 9, avg: 16.34375, max: 45)
#
# Run: 65, exploration: 0.3773857802651195, score: 11
# Scores: (min: 9, avg: 16.26153846153846, max: 45)
#
# Run: 66, exploration: 0.37250909354954626, score: 14
# Scores: (min: 9, avg: 16.227272727272727, max: 45)
#
# Run: 67, exploration: 0.3691698907910935, score: 10
# Scores: (min: 9, avg: 16.134328358208954, max: 45)
#
# Run: 68, exploration: 0.3654947603053141, score: 11
# Scores: (min: 9, avg: 16.058823529411764, max: 45)
#
# Run: 69, exploration: 0.3600505500482551, score: 16
# Scores: (min: 9, avg: 16.057971014492754, max: 45)
#
# Run: 70, exploration: 0.3568230267186975, score: 10
# Scores: (min: 9, avg: 15.971428571428572, max: 45)
#
# Run: 71, exploration: 0.3536244351789717, score: 10
# Scores: (min: 9, avg: 15.887323943661972, max: 45)
#
# Run: 72, exploration: 0.34870574454404424, score: 15
# Scores: (min: 9, avg: 15.875, max: 45)
#
# Run: 73, exploration: 0.3452343370855593, score: 11
# Scores: (min: 9, avg: 15.808219178082192, max: 45)
#
# Run: 74, exploration: 0.3424821096413374, score: 9
# Scores: (min: 9, avg: 15.716216216216216, max: 45)
#
# Run: 75, exploration: 0.33941207128512485, score: 10
# Scores: (min: 9, avg: 15.64, max: 45)
#
# Run: 76, exploration: 0.33670625926950376, score: 9
# Scores: (min: 9, avg: 15.552631578947368, max: 45)
#
# Run: 77, exploration: 0.33368799612046873, score: 10
# Scores: (min: 9, avg: 15.480519480519481, max: 45)
#
# Run: 78, exploration: 0.3306967889354559, score: 10
# Scores: (min: 9, avg: 15.41025641025641, max: 45)
#
# Run: 79, exploration: 0.32773239518253433, score: 10
# Scores: (min: 9, avg: 15.341772151898734, max: 45)
#
# Run: 80, exploration: 0.32479457450384985, score: 10
# Scores: (min: 9, avg: 15.275, max: 45)
#
# Run: 81, exploration: 0.32091840475743094, score: 13
# Scores: (min: 9, avg: 15.246913580246913, max: 45)
#
# Run: 82, exploration: 0.31867870398971, score: 8
# Scores: (min: 8, avg: 15.158536585365853, max: 45)
# Run: 83, exploration: 0.31519071309757335, score: 12
# Scores: (min: 8, avg: 15.120481927710843, max: 45)
#
# Run: 84, exploration: 0.3095652482070879, score: 19
# Scores: (min: 8, avg: 15.166666666666666, max: 45)
#
# Run: 85, exploration: 0.30373614537615473, score: 20
# Scores: (min: 8, avg: 15.223529411764705, max: 45)
#
# Run: 86, exploration: 0.3013147438372364, score: 9
# Scores: (min: 8, avg: 15.151162790697674, max: 45)
#
# Run: 87, exploration: 0.29771878754395165, score: 13
# Scores: (min: 8, avg: 15.126436781609195, max: 45)
#
# Run: 88, exploration: 0.2947549613501431, score: 11
# Scores: (min: 8, avg: 15.079545454545455, max: 45)
#
# Run: 89, exploration: 0.29211275315428575, score: 10
# Scores: (min: 8, avg: 15.02247191011236, max: 45)
#
# Run: 90, exploration: 0.28149687783101773, score: 38
# Scores: (min: 8, avg: 15.277777777777779, max: 45)
#
# Run: 91, exploration: 0.2789735162078359, score: 10
# Scores: (min: 8, avg: 15.219780219780219, max: 45)
#
# Run: 92, exploration: 0.2767495237336227, score: 9
# Scores: (min: 8, avg: 15.152173913043478, max: 45)
#
# Run: 93, exploration: 0.27126680151057403, score: 21
# Scores: (min: 8, avg: 15.21505376344086, max: 45)
#
# Run: 94, exploration: 0.2674936530982436, score: 15
# Scores: (min: 8, avg: 15.212765957446809, max: 45)
#
# Run: 95, exploration: 0.26350921379006, score: 16
# Scores: (min: 8, avg: 15.221052631578948, max: 45)
#
# Run: 96, exploration: 0.2608859480009449, score: 11
# Scores: (min: 8, avg: 15.177083333333334, max: 45)
#
# Run: 97, exploration: 0.2582887971370021, score: 11
# Scores: (min: 8, avg: 15.1340206185567, max: 45)
#
# Run: 98, exploration: 0.256229704400119, score: 9
# Scores: (min: 8, avg: 15.071428571428571, max: 45)
#
# Run: 99, exploration: 0.253171802863904, score: 13
# Scores: (min: 8, avg: 15.05050505050505, max: 45)
#
# Run: 100, exploration: 0.25115350309155987, score: 9
# Scores: (min: 8, avg: 14.99, max: 45)
#
# Run: 101, exploration: 0.24890214202456656, score: 10
# Scores: (min: 8, avg: 14.93, max: 45)
#
# Run: 102, exploration: 0.24642429138466176, score: 11
# Scores: (min: 8, avg: 14.82, max: 45)
#
# Run: 103, exploration: 0.24421532336806764, score: 10
# Scores: (min: 8, avg: 14.78, max: 45)
#
# Run: 104, exploration: 0.24130080409231539, score: 13
# Scores: (min: 8, avg: 14.73, max: 45)
#
# Run: 105, exploration: 0.2386597270564102, score: 12
# Scores: (min: 8, avg: 14.55, max: 45)
#
# Run: 106, exploration: 0.23604755704357036, score: 12
# Scores: (min: 8, avg: 14.48, max: 45)
#
# Run: 107, exploration: 0.23253152160126508, score: 16
# Scores: (min: 8, avg: 14.43, max: 45)
#
# Run: 108, exploration: 0.22883879124277842, score: 17
# Scores: (min: 8, avg: 14.35, max: 45)
#
# Run: 109, exploration: 0.2256557894266728, score: 15
# Scores: (min: 8, avg: 14.08, max: 45)
#
# Run: 110, exploration: 0.22340935901156642, score: 11
# Scores: (min: 8, avg: 14.03, max: 45)
#
# Run: 111, exploration: 0.22140669877912197, score: 10
# Scores: (min: 8, avg: 13.89, max: 45)
#
# Run: 112, exploration: 0.21898336600184118, score: 12
# Scores: (min: 8, avg: 13.74, max: 45)
#
# Run: 113, exploration: 0.21593744687294092, score: 15
# Scores: (min: 8, avg: 13.65, max: 45)
#
# Run: 114, exploration: 0.21272096064433738, score: 16
# Scores: (min: 8, avg: 13.36, max: 38)
#
# Run: 115, exploration: 0.2089243567285215, score: 19
# Scores: (min: 8, avg: 13.36, max: 38)
#
# Run: 116, exploration: 0.20581233365902327, score: 16
# Scores: (min: 8, avg: 13.22, max: 38)
#
# Run: 117, exploration: 0.20315276796804524, score: 14
# Scores: (min: 8, avg: 13.23, max: 38)
#
# Run: 118, exploration: 0.19992658861601492, score: 17
# Scores: (min: 8, avg: 13.26, max: 38)
#
# Run: 119, exploration: 0.19635833625895469, score: 19
# Scores: (min: 8, avg: 13.35, max: 38)
#
# Run: 120, exploration: 0.193433489764775, score: 16
# Scores: (min: 8, avg: 13.33, max: 38)
#
# Run: 121, exploration: 0.1913163283665175, score: 12
# Scores: (min: 8, avg: 13.32, max: 38)
#
# Run: 122, exploration: 0.1875261347249312, score: 21
# Scores: (min: 8, avg: 13.44, max: 38)
#
# Run: 123, exploration: 0.18399502414604677, score: 20
# Scores: (min: 8, avg: 13.54, max: 38)
#
# Run: 124, exploration: 0.18161738795277457, score: 14
# Scores: (min: 8, avg: 13.55, max: 38)
#
# Run: 125, exploration: 0.17927047625269885, score: 14
# Scores: (min: 8, avg: 13.48, max: 38)
#
# Run: 126, exploration: 0.175894819435018, score: 20
# Scores: (min: 8, avg: 13.58, max: 38)
#
# Run: 127, exploration: 0.1712068869723534, score: 28
# Scores: (min: 8, avg: 13.74, max: 38)
#
# Run: 128, exploration: 0.16764726910823713, score: 22
# Scores: (min: 8, avg: 13.75, max: 38)
#
# Run: 129, exploration: 0.1651500869836984, score: 16
# Scores: (min: 8, avg: 13.79, max: 38)
#
# Run: 130, exploration: 0.16252741141820165, score: 17
# Scores: (min: 8, avg: 13.82, max: 38)
#
# Run: 131, exploration: 0.15930755890168982, score: 21
# Scores: (min: 8, avg: 13.87, max: 38)
#
# Run: 132, exploration: 0.15646426738912245, score: 19
# Scores: (min: 8, avg: 13.93, max: 38)
#
# Run: 133, exploration: 0.15351805068921792, score: 20
# Scores: (min: 8, avg: 14.02, max: 38)
#
# Run: 134, exploration: 0.1501758809449194, score: 23
# Scores: (min: 8, avg: 14.09, max: 38)
#
# Run: 135, exploration: 0.14675956554434944, score: 24
# Scores: (min: 8, avg: 14.2, max: 38)
#
# Run: 136, exploration: 0.14370823986183776, score: 22
# Scores: (min: 8, avg: 14.28, max: 38)
#
# Run: 137, exploration: 0.14142607279713987, score: 17
# Scores: (min: 8, avg: 14.33, max: 38)
#
# Run: 138, exploration: 0.13931946728658592, score: 16
# Scores: (min: 8, avg: 14.36, max: 38)
#
# Run: 139, exploration: 0.13710699638012722, score: 17
# Scores: (min: 8, avg: 14.43, max: 38)
#
# Run: 140, exploration: 0.12898951166537082, score: 62
# Scores: (min: 8, avg: 14.89, max: 62)
#
# Run: 141, exploration: 0.12630764893118168, score: 22
# Scores: (min: 8, avg: 14.96, max: 62)
#
# Run: 142, exploration: 0.12455078999239512, score: 15
# Scores: (min: 8, avg: 14.95, max: 62)
#
# Run: 143, exploration: 0.12111004258082052, score: 29
# Scores: (min: 8, avg: 14.96, max: 62)
#
# Run: 144, exploration: 0.11811834750160519, score: 26
# Scores: (min: 8, avg: 15, max: 62)
#
# Run: 145, exploration: 0.11601019332960474, score: 19
# Scores: (min: 8, avg: 15.05, max: 62)
#
# Run: 146, exploration: 0.11291830038439628, score: 28
# Scores: (min: 8, avg: 15.22, max: 62)
#
# Run: 147, exploration: 0.11090295568066744, score: 19
# Scores: (min: 8, avg: 15.29, max: 62)
#
# Run: 148, exploration: 0.10805523559661097, score: 27
# Scores: (min: 8, avg: 15.43, max: 62)
#
# Run: 149, exploration: 0.10423255672364393, score: 37
# Scores: (min: 8, avg: 15.7, max: 62)
#
# Run: 150, exploration: 0.10278274825565252, score: 15
# Scores: (min: 8, avg: 15.74, max: 62)
#
# Run: 151, exploration: 0.10064575883143112, score: 22
# Scores: (min: 8, avg: 15.82, max: 62)
#
# Run: 152, exploration: 0.09865185209888758, score: 21
# Scores: (min: 8, avg: 15.89, max: 62)
#
# Run: 153, exploration: 0.09660074947521763, score: 22
# Scores: (min: 8, avg: 15.83, max: 62)
#
# Run: 154, exploration: 0.0929040264569992, score: 40
# Scores: (min: 8, avg: 16.14, max: 62)
#
# Run: 155, exploration: 0.09042795693466221, score: 28
# Scores: (min: 8, avg: 16.31, max: 62)
#
# Run: 156, exploration: 0.08925942107729658, score: 14
# Scores: (min: 8, avg: 16.33, max: 62)
#
# Run: 157, exploration: 0.08749109062109678, score: 21
# Scores: (min: 8, avg: 16.42, max: 62)
#
# Run: 158, exploration: 0.08644695274082355, score: 13
# Scores: (min: 8, avg: 16.44, max: 62)
#
# Run: 159, exploration: 0.0855007766078156, score: 12
# Scores: (min: 8, avg: 16.46, max: 62)
#
# Run: 160, exploration: 0.08448039157186232, score: 13
# Scores: (min: 8, avg: 16.48, max: 62)
#
# Run: 161, exploration: 0.08355573977468322, score: 12
# Scores: (min: 8, avg: 16.47, max: 62)
#
# Run: 162, exploration: 0.08280673911517833, score: 10
# Scores: (min: 8, avg: 16.46, max: 62)
#
# Run: 163, exploration: 0.08206445256040702, score: 10
# Scores: (min: 8, avg: 16.45, max: 62)
#
# Run: 164, exploration: 0.0812474911046467, score: 11
# Scores: (min: 8, avg: 16.45, max: 62)
#
# Run: 165, exploration: 0.08059978156138373, score: 9
# Scores: (min: 8, avg: 16.43, max: 62)
#
# Run: 166, exploration: 0.07892400538576702, score: 22
# Scores: (min: 8, avg: 16.51, max: 62)
#
# Run: 167, exploration: 0.07774839652261822, score: 16
# Scores: (min: 8, avg: 16.57, max: 62)
#
# Run: 168, exploration: 0.07666696585263952, score: 15
# Scores: (min: 8, avg: 16.61, max: 62)
#
# Run: 169, exploration: 0.07582783328659772, score: 12
# Scores: (min: 8, avg: 16.57, max: 62)
# Run: 170, exploration: 0.075, score: 22
# Scores: (min: 8, avg: 16.69, max: 62)
#
# Run: 171, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 16.69, max: 62)
#
# Run: 172, exploration: 0.075, score: 12
# Scores: (min: 8, avg: 16.66, max: 62)
#
# Run: 173, exploration: 0.075, score: 11
# Scores: (min: 8, avg: 16.66, max: 62)
#
# Run: 174, exploration: 0.075, score: 11
# Scores: (min: 8, avg: 16.68, max: 62)
#
# Run: 175, exploration: 0.075, score: 20
# Scores: (min: 8, avg: 16.78, max: 62)
#
# Run: 176, exploration: 0.075, score: 9
# Scores: (min: 8, avg: 16.78, max: 62)
#
# Run: 177, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 16.78, max: 62)
#
# Run: 178, exploration: 0.075, score: 16
# Scores: (min: 8, avg: 16.84, max: 62)
#
# Run: 179, exploration: 0.075, score: 16
# Scores: (min: 8, avg: 16.9, max: 62)
#
# Run: 180, exploration: 0.075, score: 11
# Scores: (min: 8, avg: 16.91, max: 62)
#
# Run: 181, exploration: 0.075, score: 12
# Scores: (min: 8, avg: 16.9, max: 62)
#
# Run: 182, exploration: 0.075, score: 16
# Scores: (min: 9, avg: 16.98, max: 62)
#
# Run: 183, exploration: 0.075, score: 9
# Scores: (min: 9, avg: 16.95, max: 62)
#
# Run: 184, exploration: 0.075, score: 11
# Scores: (min: 9, avg: 16.87, max: 62)
#
# Run: 185, exploration: 0.075, score: 10
# Scores: (min: 9, avg: 16.77, max: 62)
#
# Run: 186, exploration: 0.075, score: 12
# Scores: (min: 9, avg: 16.8, max: 62)
#
# Run: 187, exploration: 0.075, score: 15
# Scores: (min: 9, avg: 16.82, max: 62)
#
# Run: 188, exploration: 0.075, score: 12
# Scores: (min: 9, avg: 16.83, max: 62)
#
# Run: 189, exploration: 0.075, score: 10
# Scores: (min: 9, avg: 16.83, max: 62)
#
# Run: 190, exploration: 0.075, score: 9
# Scores: (min: 9, avg: 16.54, max: 62)
#
# Run: 191, exploration: 0.075, score: 11
# Scores: (min: 9, avg: 16.55, max: 62)
#
# Run: 192, exploration: 0.075, score: 9
# Scores: (min: 9, avg: 16.55, max: 62)
#
# Run: 193, exploration: 0.075, score: 13
# Scores: (min: 9, avg: 16.47, max: 62)
#
# Run: 194, exploration: 0.075, score: 12
# Scores: (min: 9, avg: 16.44, max: 62)
#
# Run: 195, exploration: 0.075, score: 12
# Scores: (min: 9, avg: 16.4, max: 62)
#
# Run: 196, exploration: 0.075, score: 9
# Scores: (min: 9, avg: 16.38, max: 62)
#
# Run: 197, exploration: 0.075, score: 11
# Scores: (min: 9, avg: 16.38, max: 62)
#
# Run: 198, exploration: 0.075, score: 9
# Scores: (min: 9, avg: 16.38, max: 62)
#
# Run: 199, exploration: 0.075, score: 10
# Scores: (min: 9, avg: 16.35, max: 62)
#
# Run: 200, exploration: 0.075, score: 8
# Scores: (min: 8, avg: 16.34, max: 62)
#
# Run: 201, exploration: 0.075, score: 9
# Scores: (min: 8, avg: 16.33, max: 62)
#
# Run: 202, exploration: 0.075, score: 13
# Scores: (min: 8, avg: 16.35, max: 62)
#
# Run: 203, exploration: 0.075, score: 11
# Scores: (min: 8, avg: 16.36, max: 62)
#
# Run: 204, exploration: 0.075, score: 9
# Scores: (min: 8, avg: 16.32, max: 62)
#
# Run: 205, exploration: 0.075, score: 15
# Scores: (min: 8, avg: 16.35, max: 62)
#
# Run: 206, exploration: 0.075, score: 18
# Scores: (min: 8, avg: 16.41, max: 62)
#
# Run: 207, exploration: 0.075, score: 19
# Scores: (min: 8, avg: 16.44, max: 62)
#
# Run: 208, exploration: 0.075, score: 18
# Scores: (min: 8, avg: 16.45, max: 62)
#
# Run: 209, exploration: 0.075, score: 21
# Scores: (min: 8, avg: 16.51, max: 62)
#
# Run: 210, exploration: 0.075, score: 20
# Scores: (min: 8, avg: 16.6, max: 62)
#
# Run: 211, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 16.6, max: 62)
#
# Run: 212, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 16.58, max: 62)
#
# Run: 213, exploration: 0.075, score: 20
# Scores: (min: 8, avg: 16.63, max: 62)
#
# Run: 214, exploration: 0.075, score: 12
# Scores: (min: 8, avg: 16.59, max: 62)
#
# Run: 215, exploration: 0.075, score: 24
# Scores: (min: 8, avg: 16.64, max: 62)
#
# Run: 216, exploration: 0.075, score: 11
# Scores: (min: 8, avg: 16.59, max: 62)
#
# Run: 217, exploration: 0.075, score: 89
# Scores: (min: 8, avg: 17.34, max: 89)
#
# Run: 218, exploration: 0.075, score: 30
# Scores: (min: 8, avg: 17.47, max: 89)
#
# Run: 219, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 17.38, max: 89)
#
# Run: 220, exploration: 0.075, score: 12
# Scores: (min: 8, avg: 17.34, max: 89)
#
# Run: 221, exploration: 0.075, score: 13
# Scores: (min: 8, avg: 17.35, max: 89)
#
# Run: 222, exploration: 0.075, score: 23
# Scores: (min: 8, avg: 17.37, max: 89)
#
# Run: 223, exploration: 0.075, score: 24
# Scores: (min: 8, avg: 17.41, max: 89)
#
# Run: 224, exploration: 0.075, score: 14
# Scores: (min: 8, avg: 17.41, max: 89)
#
# Run: 225, exploration: 0.075, score: 9
# Scores: (min: 8, avg: 17.36, max: 89)
#
# Run: 226, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 17.26, max: 89)
#
# Run: 227, exploration: 0.075, score: 9
# Scores: (min: 8, avg: 17.07, max: 89)
#
# Run: 228, exploration: 0.075, score: 9
# Scores: (min: 8, avg: 16.94, max: 89)
#
# Run: 229, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 16.88, max: 89)
#
# Run: 230, exploration: 0.075, score: 9
# Scores: (min: 8, avg: 16.8, max: 89)
#
# Run: 231, exploration: 0.075, score: 13
# Scores: (min: 8, avg: 16.72, max: 89)
#
# Run: 232, exploration: 0.075, score: 9
# Scores: (min: 8, avg: 16.62, max: 89)
#
# Run: 233, exploration: 0.075, score: 8
# Scores: (min: 8, avg: 16.5, max: 89)
#
# Run: 234, exploration: 0.075, score: 9
# Scores: (min: 8, avg: 16.36, max: 89)
#
# Run: 235, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 16.22, max: 89)
#
# Run: 236, exploration: 0.075, score: 9
# Scores: (min: 8, avg: 16.09, max: 89)
#
# Run: 237, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 16.02, max: 89)
#
# Run: 238, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 15.96, max: 89)
#
# Run: 239, exploration: 0.075, score: 9
# Scores: (min: 8, avg: 15.88, max: 89)
#
# Run: 240, exploration: 0.075, score: 14
# Scores: (min: 8, avg: 15.4, max: 89)
#
# Run: 241, exploration: 0.075, score: 12
# Scores: (min: 8, avg: 15.3, max: 89)
#
# Run: 242, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 15.25, max: 89)
#
# Run: 243, exploration: 0.075, score: 24
# Scores: (min: 8, avg: 15.2, max: 89)
#
# Run: 244, exploration: 0.075, score: 11
# Scores: (min: 8, avg: 15.05, max: 89)
#
# Run: 245, exploration: 0.075, score: 11
# Scores: (min: 8, avg: 14.97, max: 89)
#
# Run: 246, exploration: 0.075, score: 31
# Scores: (min: 8, avg: 15, max: 89)
#
# Run: 247, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 14.91, max: 89)
#
# Run: 248, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 14.74, max: 89)
#
# Run: 249, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 14.47, max: 89)
#
# Run: 250, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 14.42, max: 89)
#
# Run: 251, exploration: 0.075, score: 12
# Scores: (min: 8, avg: 14.32, max: 89)
#
# Run: 252, exploration: 0.075, score: 14
# Scores: (min: 8, avg: 14.25, max: 89)
#
# Run: 253, exploration: 0.075, score: 14
# Scores: (min: 8, avg: 14.17, max: 89)
#
# Run: 254, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 13.87, max: 89)
#
# Run: 255, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 13.69, max: 89)
#
# Run: 256, exploration: 0.075, score: 11
# Scores: (min: 8, avg: 13.66, max: 89)
#
# Run: 257, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 13.55, max: 89)
#
# Run: 258, exploration: 0.075, score: 9
# Scores: (min: 8, avg: 13.51, max: 89)
#
# Run: 259, exploration: 0.075, score: 11
# Scores: (min: 8, avg: 13.5, max: 89)
#
# Run: 260, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 13.47, max: 89)
#
# Run: 261, exploration: 0.075, score: 9
# Scores: (min: 8, avg: 13.44, max: 89)
#
# Run: 262, exploration: 0.075, score: 9
# Scores: (min: 8, avg: 13.43, max: 89)
#
# Run: 263, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 13.43, max: 89)
#
# Run: 264, exploration: 0.075, score: 11
# Scores: (min: 8, avg: 13.43, max: 89)
#
# Run: 265, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 13.44, max: 89)
#
# Run: 266, exploration: 0.075, score: 8
# Scores: (min: 8, avg: 13.3, max: 89)
#
# Run: 267, exploration: 0.075, score: 8
# Scores: (min: 8, avg: 13.22, max: 89)
#
# Run: 268, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 13.17, max: 89)
#
# Run: 269, exploration: 0.075, score: 9
# Scores: (min: 8, avg: 13.14, max: 89)
#
# Run: 270, exploration: 0.075, score: 9
# Scores: (min: 8, avg: 13.01, max: 89)
#
# Run: 271, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 13.01, max: 89)
#
# Run: 272, exploration: 0.075, score: 9
# Scores: (min: 8, avg: 12.98, max: 89)
#
# Run: 273, exploration: 0.075, score: 12
# Scores: (min: 8, avg: 12.99, max: 89)
#
# Run: 274, exploration: 0.075, score: 11
# Scores: (min: 8, avg: 12.99, max: 89)
# Run: 275, exploration: 0.075, score: 8
# Scores: (min: 8, avg: 12.87, max: 89)
#
# Run: 276, exploration: 0.075, score: 9
# Scores: (min: 8, avg: 12.87, max: 89)
#
# Run: 277, exploration: 0.075, score: 9
# Scores: (min: 8, avg: 12.86, max: 89)
#
# Run: 278, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 12.8, max: 89)
#
# Run: 279, exploration: 0.075, score: 9
# Scores: (min: 8, avg: 12.73, max: 89)
#
# Run: 280, exploration: 0.075, score: 9
# Scores: (min: 8, avg: 12.71, max: 89)
#
# Run: 281, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 12.69, max: 89)
#
# Run: 282, exploration: 0.075, score: 12
# Scores: (min: 8, avg: 12.65, max: 89)
#
# Run: 283, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 12.66, max: 89)
#
# Run: 284, exploration: 0.075, score: 8
# Scores: (min: 8, avg: 12.63, max: 89)
#
# Run: 285, exploration: 0.075, score: 14
# Scores: (min: 8, avg: 12.67, max: 89)
#
# Run: 286, exploration: 0.075, score: 9
# Scores: (min: 8, avg: 12.64, max: 89)
#
# Run: 287, exploration: 0.075, score: 26
# Scores: (min: 8, avg: 12.75, max: 89)
#
# Run: 288, exploration: 0.075, score: 58
# Scores: (min: 8, avg: 13.21, max: 89)
#
# Run: 289, exploration: 0.075, score: 33
# Scores: (min: 8, avg: 13.44, max: 89)
#
# Run: 290, exploration: 0.075, score: 14
# Scores: (min: 8, avg: 13.49, max: 89)
#
# Run: 291, exploration: 0.075, score: 24
# Scores: (min: 8, avg: 13.62, max: 89)
#
# Run: 292, exploration: 0.075, score: 16
# Scores: (min: 8, avg: 13.69, max: 89)
#
# Run: 293, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 13.66, max: 89)
#
# Run: 294, exploration: 0.075, score: 9
# Scores: (min: 8, avg: 13.63, max: 89)
#
# Run: 295, exploration: 0.075, score: 37
# Scores: (min: 8, avg: 13.88, max: 89)
#
# Run: 296, exploration: 0.075, score: 13
# Scores: (min: 8, avg: 13.92, max: 89)
#
# Run: 297, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 13.91, max: 89)
#
# Run: 298, exploration: 0.075, score: 15
# Scores: (min: 8, avg: 13.97, max: 89)
#
# Run: 299, exploration: 0.075, score: 35
# Scores: (min: 8, avg: 14.22, max: 89)
#
# Run: 300, exploration: 0.075, score: 52
# Scores: (min: 8, avg: 14.66, max: 89)
#
# Run: 301, exploration: 0.075, score: 32
# Scores: (min: 8, avg: 14.89, max: 89)
#
# Run: 302, exploration: 0.075, score: 8
# Scores: (min: 8, avg: 14.84, max: 89)
#
# Run: 303, exploration: 0.075, score: 11
# Scores: (min: 8, avg: 14.84, max: 89)
#
# Run: 304, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 14.85, max: 89)
#
# Run: 305, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 14.8, max: 89)
#
# Run: 306, exploration: 0.075, score: 9
# Scores: (min: 8, avg: 14.71, max: 89)
#
# Run: 307, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 14.62, max: 89)
#
# Run: 308, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 14.54, max: 89)
#
# Run: 309, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 14.43, max: 89)
#
# Run: 310, exploration: 0.075, score: 9
# Scores: (min: 8, avg: 14.32, max: 89)
#
# Run: 311, exploration: 0.075, score: 8
# Scores: (min: 8, avg: 14.3, max: 89)
#
# Run: 312, exploration: 0.075, score: 11
# Scores: (min: 8, avg: 14.31, max: 89)
#
# Run: 313, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 14.21, max: 89)
#
# Run: 314, exploration: 0.075, score: 11
# Scores: (min: 8, avg: 14.2, max: 89)
#
# Run: 315, exploration: 0.075, score: 30
# Scores: (min: 8, avg: 14.26, max: 89)
#
# Run: 316, exploration: 0.075, score: 8
# Scores: (min: 8, avg: 14.23, max: 89)
#
# Run: 317, exploration: 0.075, score: 12
# Scores: (min: 8, avg: 13.46, max: 58)
#
# Run: 318, exploration: 0.075, score: 9
# Scores: (min: 8, avg: 13.25, max: 58)
#
# Run: 319, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 13.25, max: 58)
#
# Run: 320, exploration: 0.075, score: 11
# Scores: (min: 8, avg: 13.24, max: 58)
#
# Run: 321, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 13.21, max: 58)
#
# Run: 322, exploration: 0.075, score: 9
# Scores: (min: 8, avg: 13.07, max: 58)
#
# Run: 323, exploration: 0.075, score: 9
# Scores: (min: 8, avg: 12.92, max: 58)
#
# Run: 324, exploration: 0.075, score: 9
# Scores: (min: 8, avg: 12.87, max: 58)
#
# Run: 325, exploration: 0.075, score: 25
# Scores: (min: 8, avg: 13.03, max: 58)
#
# Run: 326, exploration: 0.075, score: 45
# Scores: (min: 8, avg: 13.38, max: 58)
#
# Run: 327, exploration: 0.075, score: 13
# Scores: (min: 8, avg: 13.42, max: 58)
#
# Run: 328, exploration: 0.075, score: 31
# Scores: (min: 8, avg: 13.64, max: 58)
#
# Run: 329, exploration: 0.075, score: 24
# Scores: (min: 8, avg: 13.78, max: 58)
#
# Run: 330, exploration: 0.075, score: 74
# Scores: (min: 8, avg: 14.43, max: 74)
#
# Run: 331, exploration: 0.075, score: 28
# Scores: (min: 8, avg: 14.58, max: 74)
#
# Run: 332, exploration: 0.075, score: 10
# Scores: (min: 8, avg: 14.59, max: 74)
#
# Run: 333, exploration: 0.075, score: 42
# Scores: (min: 8, avg: 14.93, max: 74)
#
# Run: 334, exploration: 0.075, score: 21
# Scores: (min: 8, avg: 15.05, max: 74)
#
# Run: 335, exploration: 0.075, score: 15
# Scores: (min: 8, avg: 15.1, max: 74)
#
# Run: 336, exploration: 0.075, score: 13
# Scores: (min: 8, avg: 15.14, max: 74)
#
# Run: 337, exploration: 0.075, score: 23
# Scores: (min: 8, avg: 15.27, max: 74)
#
# Run: 338, exploration: 0.075, score: 36
# Scores: (min: 8, avg: 15.53, max: 74)
#
# Run: 339, exploration: 0.075, score: 12
# Scores: (min: 8, avg: 15.56, max: 74)
#
# Run: 340, exploration: 0.075, score: 71
# Scores: (min: 8, avg: 16.13, max: 74)
#
# Run: 341, exploration: 0.075, score: 59
# Scores: (min: 8, avg: 16.6, max: 74)
#
# Run: 342, exploration: 0.075, score: 103
# Scores: (min: 8, avg: 17.53, max: 103)
#
# Run: 343, exploration: 0.075, score: 69
# Scores: (min: 8, avg: 17.98, max: 103)
#
# Run: 344, exploration: 0.075, score: 81
# Scores: (min: 8, avg: 18.68, max: 103)
#
# Run: 345, exploration: 0.075, score: 130
# Scores: (min: 8, avg: 19.87, max: 130)
#
# Run: 346, exploration: 0.075, score: 67
# Scores: (min: 8, avg: 20.23, max: 130)
#
# Run: 347, exploration: 0.075, score: 67
# Scores: (min: 8, avg: 20.8, max: 130)
#
# Run: 348, exploration: 0.075, score: 156
# Scores: (min: 8, avg: 22.26, max: 156)
#
# Run: 349, exploration: 0.075, score: 147
# Scores: (min: 8, avg: 23.63, max: 156)
#
# Run: 350, exploration: 0.075, score: 139
# Scores: (min: 8, avg: 24.92, max: 156)
#
# Run: 351, exploration: 0.075, score: 72
# Scores: (min: 8, avg: 25.52, max: 156)
#
# Run: 352, exploration: 0.075, score: 130
# Scores: (min: 8, avg: 26.68, max: 156)
#
# Run: 353, exploration: 0.075, score: 88
# Scores: (min: 8, avg: 27.42, max: 156)
#
# Run: 354, exploration: 0.075, score: 109
# Scores: (min: 8, avg: 28.41, max: 156)
#
# Run: 355, exploration: 0.075, score: 102
# Scores: (min: 8, avg: 29.33, max: 156)
#
# Run: 356, exploration: 0.075, score: 92
# Scores: (min: 8, avg: 30.14, max: 156)
#
# Run: 357, exploration: 0.075, score: 80
# Scores: (min: 8, avg: 30.84, max: 156)
#
# Run: 358, exploration: 0.075, score: 93
# Scores: (min: 8, avg: 31.68, max: 156)
#
# Run: 359, exploration: 0.075, score: 157
# Scores: (min: 8, avg: 33.14, max: 157)
#
# Run: 360, exploration: 0.075, score: 78
# Scores: (min: 8, avg: 33.82, max: 157)
#
# Run: 361, exploration: 0.075, score: 82
# Scores: (min: 8, avg: 34.55, max: 157)
#
# Run: 362, exploration: 0.075, score: 45
# Scores: (min: 8, avg: 34.91, max: 157)
#
# Run: 363, exploration: 0.075, score: 83
# Scores: (min: 8, avg: 35.64, max: 157)
#
# Run: 364, exploration: 0.075, score: 58
# Scores: (min: 8, avg: 36.11, max: 157)
#
# Run: 365, exploration: 0.075, score: 58
# Scores: (min: 8, avg: 36.59, max: 157)
#
# Run: 366, exploration: 0.075, score: 65
# Scores: (min: 8, avg: 37.16, max: 157)
#
# Run: 367, exploration: 0.075, score: 53
# Scores: (min: 8, avg: 37.61, max: 157)
#
# Run: 368, exploration: 0.075, score: 83
# Scores: (min: 8, avg: 38.34, max: 157)
#
# Run: 369, exploration: 0.075, score: 58
# Scores: (min: 8, avg: 38.83, max: 157)
#
# Run: 370, exploration: 0.075, score: 68
# Scores: (min: 8, avg: 39.42, max: 157)
#
# Run: 371, exploration: 0.075, score: 81
# Scores: (min: 8, avg: 40.13, max: 157)
#
# Run: 372, exploration: 0.075, score: 90
# Scores: (min: 8, avg: 40.94, max: 157)
#
# Run: 373, exploration: 0.075, score: 88
# Scores: (min: 8, avg: 41.7, max: 157)
#
# Run: 374, exploration: 0.075, score: 85
# Scores: (min: 8, avg: 42.44, max: 157)
#
# Run: 375, exploration: 0.075, score: 95
# Scores: (min: 8, avg: 43.31, max: 157)
#
# Run: 376, exploration: 0.075, score: 88
# Scores: (min: 8, avg: 44.1, max: 157)
#
# Run: 377, exploration: 0.075, score: 418
# Scores: (min: 8, avg: 48.19, max: 418)
#
# Run: 378, exploration: 0.075, score: 102
# Scores: (min: 8, avg: 49.11, max: 418)
# Run: 379, exploration: 0.075, score: 142
# Scores: (min: 8, avg: 50.44, max: 418)
#
# Run: 380, exploration: 0.075, score: 113
# Scores: (min: 8, avg: 51.48, max: 418)
#
# Run: 381, exploration: 0.075, score: 115
# Scores: (min: 8, avg: 52.53, max: 418)
#
# Run: 382, exploration: 0.075, score: 500
# Scores: (min: 8, avg: 57.41, max: 500)
#
# Run: 383, exploration: 0.075, score: 500
# Scores: (min: 8, avg: 62.31, max: 500)
#
# Run: 384, exploration: 0.075, score: 292
# Scores: (min: 8, avg: 65.15, max: 500)
#
# Run: 385, exploration: 0.075, score: 342
# Scores: (min: 8, avg: 68.43, max: 500)
#
# Run: 386, exploration: 0.075, score: 262
# Scores: (min: 8, avg: 70.96, max: 500)
#
# Run: 387, exploration: 0.075, score: 500
# Scores: (min: 8, avg: 75.7, max: 500)
#
# Run: 388, exploration: 0.075, score: 155
# Scores: (min: 8, avg: 76.67, max: 500)
#
# Run: 389, exploration: 0.075, score: 101
# Scores: (min: 8, avg: 77.35, max: 500)
#
# Run: 390, exploration: 0.075, score: 500
# Scores: (min: 8, avg: 82.21, max: 500)
#
# Run: 391, exploration: 0.075, score: 500
# Scores: (min: 8, avg: 86.97, max: 500)
#
# Run: 392, exploration: 0.075, score: 500
# Scores: (min: 8, avg: 91.81, max: 500)
#
# Run: 393, exploration: 0.075, score: 500
# Scores: (min: 8, avg: 96.71, max: 500)
#
# Run: 394, exploration: 0.075, score: 500
# Scores: (min: 8, avg: 101.62, max: 500)
#
# Run: 395, exploration: 0.075, score: 500
# Scores: (min: 8, avg: 106.25, max: 500)
#
# Run: 396, exploration: 0.075, score: 500
# Scores: (min: 8, avg: 111.12, max: 500)
#
# Run: 397, exploration: 0.075, score: 500
# Scores: (min: 8, avg: 116.02, max: 500)
#
# Run: 398, exploration: 0.075, score: 500
# Scores: (min: 8, avg: 120.87, max: 500)
#
# Run: 399, exploration: 0.075, score: 500
# Scores: (min: 8, avg: 125.52, max: 500)
#
# Run: 400, exploration: 0.075, score: 500
# Scores: (min: 8, avg: 130, max: 500)
#
# Run: 401, exploration: 0.075, score: 500
# Scores: (min: 8, avg: 134.68, max: 500)
#
# Run: 402, exploration: 0.075, score: 500
# Scores: (min: 8, avg: 139.6, max: 500)
#
# Run: 403, exploration: 0.075, score: 500
# Scores: (min: 8, avg: 144.49, max: 500)
#
# Run: 404, exploration: 0.075, score: 500
# Scores: (min: 8, avg: 149.39, max: 500)
#
# Run: 405, exploration: 0.075, score: 500
# Scores: (min: 8, avg: 154.29, max: 500)
#
# Run: 406, exploration: 0.075, score: 500
# Scores: (min: 8, avg: 159.2, max: 500)
#
# Run: 407, exploration: 0.075, score: 500
# Scores: (min: 8, avg: 164.1, max: 500)
#
# Run: 408, exploration: 0.075, score: 500
# Scores: (min: 8, avg: 169, max: 500)
#
# Run: 409, exploration: 0.075, score: 500
# Scores: (min: 8, avg: 173.9, max: 500)
#
# Run: 410, exploration: 0.075, score: 500
# Scores: (min: 8, avg: 178.81, max: 500)
#
# Run: 411, exploration: 0.075, score: 500
# Scores: (min: 8, avg: 183.73, max: 500)
#
# Run: 412, exploration: 0.075, score: 500
# Scores: (min: 8, avg: 188.62, max: 500)
#
# Run: 413, exploration: 0.075, score: 500
# Scores: (min: 8, avg: 193.52, max: 500)
#
# Run: 414, exploration: 0.075, score: 500
# Scores: (min: 8, avg: 198.41, max: 500)
#
# Solved in 314 runs, 414 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-8-7fb3cf68102f> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
#     In this particular scenario, the agent's objective is to balance a pole on top of a cart that is moving along a frictionless track in either the left or right directions. If the pole falls in either the left or right direction, then it will result in a failure for the agent. There are about four states that he agent will be put through: Starting state, Left Correction, Right Correction, and Ending State. The goal is to accomplish an average score of 195. The algorithm used in order to solve this problem is known as Q-Learning. Q-learning is a model-free reinforcement learning method in which the agent will determine the best action to perform based on the current state the agent is in (Banoula, 2023).
#
#     According to an article written by Jordi Torres, experience replay is the act of sampling small batches of tuples from a replay buffer (using past experiences for datasets rather than the most recent experience), in order to run an individual tuple multiple times to learn the best outcomes of that particular scenario (TORRES.AI, 2021). Depending on the type of action being performed, the reward can be given at a discounted rate. This "Discount Reward" exists to determine the importance of a reward based on the state the agent is in (Banoula, 2023), making a reward worth more the closer the agent is to the ending objective typically.
#
#     Standard Q-learning uses state-action pairs to Q-values wehre deep Q-learning utilizes (action, Q-value) pairs and typically containstwo neural networks in its learning process (Singh, 2022). Since Q-learning is capable of running smaller data samples through the means of replay buffer and experience replay, it allows for less memory requirements of the neural networks while testing. One of the key differences in altering the learning rate of the algorithm is that it appeared to complete the runs either quicker or slower. Howerver, it should also be noted that making small changes to the already existing code seemed to make the agent learn the game quicker (completed in less runs) than drastically changing it which caused it to run more instances.
#
# Resources:
#
# Banoula, M. (2023, February 22). What is Q-learning: Everything you need to know: Simplilearn. Simplilearn.com. https://www.simplilearn.com/tutorials/machine-learning-tutorial/what-is-q-learning
#
# Singh, S. (2022, October 7). A comprehensive guide to neural networks in Deep Q-Learning. A Comprehensive Guide to Neural Networks in Deep Q-learning. https://www.turing.com/kb/how-are-neural-networks-used-in-deep-q-learning
#
# TORRES.AI, J. (2021, May 10). Deep Q-Network (DQN)-II. Medium. https://towardsdatascience.com/deep-q-network-dqn-ii-b6bf911b6b2c
